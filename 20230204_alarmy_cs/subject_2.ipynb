# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx', sheet_name='2번 문제')

# %%
df
# Out:
#    Ticket ID        Source Created Date  \
# 0     618330  android_mail   2022-11-09
# 1     618240  android_mail   2022-11-09
# 2     618179  android_mail   2022-11-08
# 3     618139  android_mail   2022-11-08
# 4     618099  android_mail   2022-11-08
# 5     617979  android_mail   2022-11-08
# 6     617651  android_mail   2022-11-06
# 7     617565  android_mail   2022-11-06
#
#                                          Description App version  OS version  \
# 0  Since the latest update, my alarms are default...     5.41.06        12.0
# 1  Alarmy is not overwriting silent/vibrating mod...     5.41.06        12.0
# 2  Please make alarm ringtone more loud because I...     5.41.06         9.0
# 3  The volume is now tied to my phone's media vol...     5.41.06         9.0
# 4  Randomly alarmy will just stop making sound al...     5.41.06        13.0
# 5                           No sound, just vibration     5.41.06        12.0
# ...
