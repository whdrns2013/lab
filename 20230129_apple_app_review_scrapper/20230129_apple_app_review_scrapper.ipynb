# %%
# 페이지 탐색

from bs4 import BeautifulSoup
import urllib.request

page_num = 2
url_start = 'https://itunes.apple.com/kr/rss/customerreviews/page='
url_end = '/id=1163786766/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1163786766/sortBy=mostRecent/xml'
html = urllib.request.urlopen(url_start + str(page_num) + url_end)

# Beautiful Soup 만들기
soup = BeautifulSoup(html, 'html.parser')
soup.find_all('entry')
# Out:
# [<entry>
#  <id>9406876343</id>
#  <title>좋습니다</title>
#  <content type="text">정말 짜증나게해서 일어나기 좋습니다 ㅎㅎ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-17T11:58:05-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>인천송도</name><uri>https://itunes.apple.com/kr/reviews/id953095916</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;좋습니다&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;정말 짜증나게해서 일어나기 좋습니다 ㅎㅎ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9404027834</id>
#  <title>지각ㅡㅡ</title>
#  <content type="text">최근에 세번이나지각함. 알라미도 적응되서 한 5개를 맞춰놓고 자는데 처음꺼를 끄고나서인지 뭔지는 몰라도 계속 무음으로울려서 회사 지각 최근에 세번함. 진짜 잘리기 일보직전. 갤럭시때는 배터리충전을 안하고쓴날 너무 잘울려버리는탓에 폰방전되서 지각한적은있어도 무음전환된적없는데 아이폰은 이거 안쓰는게답이네요. 백그라운드에서 무음으로 계속 울리고있었음. 너무짜증나요 진짜 아이폰유저 쓰지마세요 너무믿지마세요 어느날 지각하는 날 꼭 옴. 그게엄청중요한날일수도 있고.. 전 이제 놓아주렵니다</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-12-16T17:42:09-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>wkdiejf</name><uri>https://itunes.apple.com/kr/reviews/id1478247460</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;지각ㅡㅡ&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;최근에 세번이나지각함. 알라미도 적응되서 한 5개를 맞춰놓고 자는데 처음꺼를 끄고나서인지 뭔지는 몰라도 계속 무음으로울려서 회사 지각 최근에 세번함. 진짜 잘리기 일보직전. 갤럭시때는 배터리충전을 안하고쓴날 너무 잘울려버리는탓에 폰방전되서 지각한적은있어도 무음전환된적없는데 아이폰은 이거 안쓰는게답이네요. 백그라운드에서 무음으로 계속 울리고있었음. 너무짜증나요 진짜 아이폰유저 쓰지마세요 너무믿지마세요 어느날 지각하는 날 꼭 옴. 그게엄청중요한날일수도 있고.. 전 이제 놓아주렵니다&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9401766364</id>
#  <title>이 앱 무조건 까셈</title>
#  <content type="text">이거 개좋음 ㅋㅋ 이거 왜 안깔아요 ㄹㅇ ㅠㅠ 진짜 아침에 일어나기 쌉가능</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-16T03:11:00-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>asdfghq0</name><uri>https://itunes.apple.com/kr/reviews/id1284888572</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;이 앱 무조건 까셈&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;이거 개좋음 ㅋㅋ 이거 왜 안깔아요 ㄹㅇ ㅠㅠ 진짜 아침에 일어나기 쌉가능&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9399800963</id>
#  <title>알라미</title>
#  <content type="text">알람 맞출 때 직빵으로 이것만한 어플이 없는 것 같은데 알람 맞출 때 키패드가 아닌 스크롤바로 조정해야해서 조금 어려워요.ㅜㅜㅜ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-15T12:34:51-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>예인디</name><uri>https://itunes.apple.com/kr/reviews/id1464335416</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알라미&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;알람 맞출 때 직빵으로 이것만한 어플이 없는 것 같은데 알람 맞출 때 키패드가 아닌 스크롤바로 조정해야해서 조금 어려워요.ㅜㅜㅜ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9399419475</id>
#  <title>너무 좋아요</title>
#  <content type="text">휴대폰 앱 자체 알람이 고장나서 앱을 설치해봤는데 너무 좋은것같아요.그리고 소리가 잠이 완전 잘깨네요 문제푸는것도 재밌어요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-15T09:56:29-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>전교일등의발악</name><uri>https://itunes.apple.com/kr/reviews/id1430032470</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;너무 좋아요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;휴대폰 앱 자체 알람이 고장나서 앱을 설치해봤는데 너무 좋은것같아요.그리고 소리가 잠이 완전 잘깨네요 문제푸는것도 재밌어요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9396397819</id>
#  <title>흔들기 기능 오류..</title>
#  <content type="text">아무리 흔들어도 카운트가 안줄어들어요 ㅠ 어플을 지워야
#  알람을 끌수있네용 ..</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>3</im:rating>
#  <updated>2022-12-14T13:04:36-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>기가막힌새램</name><uri>https://itunes.apple.com/kr/reviews/id1237883315</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;흔들기 기능 오류..&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;아무리 흔들어도 카운트가 안줄어들어요 ㅠ 어플을 지워야&lt;br/&gt;알람을 끌수있네용 ..&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9392316697</id>
#  <title>배터리소모</title>
#  <content type="text">제 수험생활의 기상을 책임져준 고마운 앱이에요
#  미션으로 사진찍기 설정해두면 어쩔수없이 꾸역꾸역 일어남
#  근데..배터리 소모가 너무~~커요 정말
#  한번은 휴대폰 배터리가 95퍼센트길래 충전기를 안꼽아놓고 잤는데 다음날 알라미때문에 배터리가 5퍼센트가 되어있었어요
#  이 점만 고쳐준다면 정말 좋은 앱인데 ㅠㅠ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>3</im:rating>
#  <updated>2022-12-13T08:46:33-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>줽뛝꿃</name><uri>https://itunes.apple.com/kr/reviews/id1031545355</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;배터리소모&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;제 수험생활의 기상을 책임져준 고마운 앱이에요&lt;br/&gt;미션으로 사진찍기 설정해두면 어쩔수없이 꾸역꾸역 일어남&lt;br/&gt;근데..배터리 소모가 너무~~커요 정말&lt;br/&gt;한번은 휴대폰 배터리가 95퍼센트길래 충전기를 안꼽아놓고 잤는데 다음날 알라미때문에 배터리가 5퍼센트가 되어있었어요&lt;br/&gt;이 점만 고쳐준다면 정말 좋은 앱인데 ㅠㅠ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9389727120</id>
#  <title>거실에 가따노세요</title>
#  <content type="text">침대옆에놔두면 전.그냥,삭제하게되더라구요
#  알람울릴때ㅋ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-12T15:02:28-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>린2의추억</name><uri>https://itunes.apple.com/kr/reviews/id638016217</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;거실에 가따노세요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;침대옆에놔두면 전.그냥,삭제하게되더라구요&lt;br/&gt;알람울릴때ㅋ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9389618959</id>
#  <title>진동만 울려요</title>
#  <content type="text">소리가 안나요 소리 켜놨는데 진동만 울려요 시험기간이려서 믿었는데 늦게 일어났네요 짜증나요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>4</im:rating>
#  <updated>2022-12-12T14:15:29-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>똥꼬가 여린 공룡</name><uri>https://itunes.apple.com/kr/reviews/id1401650318</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;진동만 울려요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;소리가 안나요 소리 켜놨는데 진동만 울려요 시험기간이려서 믿었는데 늦게 일어났네요 짜증나요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9387804392</id>
#  <title>ㅎ</title>
#  <content type="text">좋아요! 중요한날에 쓰기 좋아용구리구리</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>4</im:rating>
#  <updated>2022-12-12T02:58:50-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>홍주하</name><uri>https://itunes.apple.com/kr/reviews/id886596858</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;ㅎ&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;좋아요! 중요한날에 쓰기 좋아용구리구리&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9383537343</id>
#  <title>진짜 개같이 만들었네</title>
#  <content type="text">한시간동안 흔들었는데 카운트 안 줄어들고 알람 안 꺼져서 앱 삭제했다</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>1</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-12-10T21:34:58-07:00</updated>
#  <im:version>6.75.0</im:version>
#  <author><name>나라앚</name><uri>https://itunes.apple.com/kr/reviews/id674192227</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;진짜 개같이 만들었네&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;한시간동안 흔들었는데 카운트 안 줄어들고 알람 안 꺼져서 앱 삭제했다&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9377592733</id>
#  <title>알림의 혁신</title>
#  <content type="text">휴대폰에 기본으로 설정되어 있는 알람은 많이, 시끄럽게 설정해둬도 절대 깨지 않던 사람이었습니다.
#  이 앱을 깔고 나서부터 알림 소리는 무조건 듣게 되었구요 첨에 수학문제 풀기로 설정해놨더니 풀고 자버려서 화장실 세면대 사진 찍기로 바꿧습니다. 한 번도 일어난 적 없던 제가 바꾸고 나서부터 매일 새벽 5시에 일어나게 되었어요
#  덕분에 아침공부도 하고 있어 기분이 너무 좋아요 갓생사는 느낌이라 하루하루가 즐겁습니다. 감사합니다 정말</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-09T06:37:04-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>제발 봐주세요 운영자님 제발제발젤발</name><uri>https://itunes.apple.com/kr/reviews/id1136828014</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알림의 혁신&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;휴대폰에 기본으로 설정되어 있는 알람은 많이, 시끄럽게 설정해둬도 절대 깨지 않던 사람이었습니다.&lt;br/&gt;이 앱을 깔고 나서부터 알림 소리는 무조건 듣게 되었구요 첨에 수학문제 풀기로 설정해놨더니 풀고 자버려서 화장실 세면대 사진 찍기로 바꿧습니다. 한 번도 일어난 적 없던 제가 바꾸고 나서부터 매일 새벽 5시에 일어나게 되었어요&lt;br/&gt;덕분에 아침공부도 하고 있어 기분이 너무 좋아요 갓생사는 느낌이라 하루하루가 즐겁습니다. 감사합니다 정말&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9375698170</id>
#  <title>알람이 안울려요</title>
#  <content type="text">무음모드도 아니고 백그라운드에서 끄지도 않았는데 울리지 않을 때가 많아요 요즘 ㅠㅠㅠ 혹시 몰라서 맞춰둔 기본 알람 어플에 일어나서 폰 하고 있다가 사운드가 조절이 안되고 최대로 계속 맞춰질 때 백그라운드에 켜져있던 알라미 어플로 들어가보면 그제서야 알람이 울려요 ㅠ ㅠㅠㅠㅠㅠ 여지껏 잘 써왔는데 근 몇주간 이러네요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-12-08T17:45:26-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>밈먐몸</name><uri>https://itunes.apple.com/kr/reviews/id180145827</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알람이 안울려요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;무음모드도 아니고 백그라운드에서 끄지도 않았는데 울리지 않을 때가 많아요 요즘 ㅠㅠㅠ 혹시 몰라서 맞춰둔 기본 알람 어플에 일어나서 폰 하고 있다가 사운드가 조절이 안되고 최대로 계속 맞춰질 때 백그라운드에 켜져있던 알라미 어플로 들어가보면 그제서야 알람이 울려요 ㅠ ㅠㅠㅠㅠㅠ 여지껏 잘 써왔는데 근 몇주간 이러네요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9374291529</id>
#  <title>잘쓰고있다 어느순간 스페인어로 바뀜</title>
#  <content type="text">모가 뭔지 하나도모르겠어서 못쓰겠어요
#  진짜 몇년 쓴 어플인데..
#  스페인어로 바껴서 한글이 1도 안보여요
#  어떻게 언어설정 한국어로 바꾸나요?</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>4</im:rating>
#  <updated>2022-12-08T08:03:02-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>mimm18</name><uri>https://itunes.apple.com/kr/reviews/id434622169</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;잘쓰고있다 어느순간 스페인어로 바뀜&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;모가 뭔지 하나도모르겠어서 못쓰겠어요&lt;br/&gt;진짜 몇년 쓴 어플인데..&lt;br/&gt;스페인어로 바껴서 한글이 1도 안보여요&lt;br/&gt;어떻게 언어설정 한국어로 바꾸나요?&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9371718348</id>
#  <title>저 이거 아니면 아침에 못일어나요ㅠㅠ</title>
#  <content type="text">제가 진짜 천하의 게으름뱅이입니다!! 하루에 15시간도 자는 녀석이에요ㅠㅠ 잠만보 나무늘보!! 그게 접니다!! 그렇게 인생이 낭비되고 무기력한 나날을 보내는 저에게 선물같은 어플이 이거에요 제 인생을 바꿔주셔서 감사합니다! case by case지만, 이 어플 사용한지 좀 되었는데 계산하기 퍼즐? 그동안의 저한텐 다 소용이 없었어요….그건 다 풀고 다시 자더라구요…ㅠㅠ 그러다 소용이 있었던 미션은 바로 사진찍기!!! 잠자리 옆에 미리 물떠다놓고 그 물컵을 사진만 찍으면 됩니다….ㅠㅠ 물마시면서 정신차려지고 일어나요…..지금은 이제 제 기분의 저항없이 기분나쁘지 않게 일어나요!!! 감사합니다!!!!</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-07T14:21:55-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>헤이호후</name><uri>https://itunes.apple.com/kr/reviews/id597026819</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;저 이거 아니면 아침에 못일어나요ㅠㅠ&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;제가 진짜 천하의 게으름뱅이입니다!! 하루에 15시간도 자는 녀석이에요ㅠㅠ 잠만보 나무늘보!! 그게 접니다!! 그렇게 인생이 낭비되고 무기력한 나날을 보내는 저에게 선물같은 어플이 이거에요 제 인생을 바꿔주셔서 감사합니다! case by case지만, 이 어플 사용한지 좀 되었는데 계산하기 퍼즐? 그동안의 저한텐 다 소용이 없었어요….그건 다 풀고 다시 자더라구요…ㅠㅠ 그러다 소용이 있었던 미션은 바로 사진찍기!!! 잠자리 옆에 미리 물떠다놓고 그 물컵을 사진만 찍으면 됩니다….ㅠㅠ 물마시면서 정신차려지고 일어나요…..지금은 이제 제 기분의 저항없이 기분나쁘지 않게 일어나요!!! 감사합니다!!!!&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9371661693</id>
#  <title>2</title>
#  <content type="text">왜 알람이 2일 뒤로 설정 돼어있냐고요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-12-07T13:56:29-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>디보디보짱</name><uri>https://itunes.apple.com/kr/reviews/id263667679</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;2&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;왜 알람이 2일 뒤로 설정 돼어있냐고요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9369427489</id>
#  <title>알람이 안울려요 ;</title>
#  <content type="text">ㅋㅋ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-12-06T23:08:05-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>jdvkyrg</name><uri>https://itunes.apple.com/kr/reviews/id1475042333</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알람이 안울려요 ;&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;ㅋㅋ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9366798487</id>
#  <title>효과 진짜 좋아요</title>
#  <content type="text">미션을 흔들기 하나만 하고 잤는데 아침에 그거 하느라 힘이 다빠져서 잠이 확 깨네요! 너무 좋아요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-06T05:07:24-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>곤듀병</name><uri>https://itunes.apple.com/kr/reviews/id1231126142</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;효과 진짜 좋아요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;미션을 흔들기 하나만 하고 잤는데 아침에 그거 하느라 힘이 다빠져서 잠이 확 깨네요! 너무 좋아요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9363259339</id>
#  <title>너무 좋아요</title>
#  <content type="text">너무 편함</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-05T04:50:51-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>김밥맨돌이</name><uri>https://itunes.apple.com/kr/reviews/id1345280203</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;너무 좋아요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;너무 편함&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9360570745</id>
#  <title>효과가 좋습니다</title>
#  <content type="text">가끔 안 울릴때가 있긴한데 효과는 좋습니다
#  이젠 맨정신에 알람소리 들어도 토가 쏠려요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-12-04T09:30:49-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>일찍일어나기싫어요</name><uri>https://itunes.apple.com/kr/reviews/id1474226572</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;효과가 좋습니다&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;가끔 안 울릴때가 있긴한데 효과는 좋습니다&lt;br/&gt;이젠 맨정신에 알람소리 들어도 토가 쏠려요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9356369252</id>
#  <title>다 좋은데..</title>
#  <content type="text">문제를 풀고 하면서 뇌를 깨우는건 너무너무 좋은데
#  백그라운드에 계속 켜놓아야해서 너무너무너무너무 불편해요! 제발 고쳐주세요.</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>3</im:rating>
#  <updated>2022-12-03T06:59:58-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>김한음</name><uri>https://itunes.apple.com/kr/reviews/id1195123156</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;다 좋은데..&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;문제를 풀고 하면서 뇌를 깨우는건 너무너무 좋은데&lt;br/&gt;백그라운드에 계속 켜놓아야해서 너무너무너무너무 불편해요! 제발 고쳐주세요.&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9353326387</id>
#  <title>자고 일어나니까 스페인어?로 세팅되었어요</title>
#  <content type="text">1년 결제해서 8만원 돈 주고 쓰는데, 사용한 지 몇 개월 되지 않았습니다.
#  자고 일어났는데 어플의 모든 설정들이 스페인어로 바뀌어 있어요.
#  문의 메일 보냈는데, 한글로 바꾸는 방법을 알려주는 게 아니라 어떤 게 문제인지 모르겠고 버그가 개선되는 방향으로 업데이트 한다는  피드백만 받았네요..
#  업데이트 떠서 앱 업데이트를 했는데도 여전히 스페인어(로 추정)가 떠 있네요.
#  한글로 바꾸는 언어 설정 옵션 같은 거는 여전히 보이지 않고요.
#  돈을 주고 쓰는데, 무슨 말인지도 몰라서 쓰지 못하고 있습니다.</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>3</im:rating>
#  <updated>2022-12-02T10:52:48-07:00</updated>
#  <im:version>6.74.0</im:version>
#  <author><name>별명은 영어로 닉네임</name><uri>https://itunes.apple.com/kr/reviews/id481288989</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;자고 일어나니까 스페인어?로 세팅되었어요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;1년 결제해서 8만원 돈 주고 쓰는데, 사용한 지 몇 개월 되지 않았습니다.&lt;br/&gt;자고 일어났는데 어플의 모든 설정들이 스페인어로 바뀌어 있어요.&lt;br/&gt;문의 메일 보냈는데, 한글로 바꾸는 방법을 알려주는 게 아니라 어떤 게 문제인지 모르겠고 버그가 개선되는 방향으로 업데이트 한다는  피드백만 받았네요..&lt;br/&gt;업데이트 떠서 앱 업데이트를 했는데도 여전히 스페인어(로 추정)가 떠 있네요.&lt;br/&gt;한글로 바꾸는 언어 설정 옵션 같은 거는 여전히 보이지 않고요.&lt;br/&gt;돈을 주고 쓰는데, 무슨 말인지도 몰라서 쓰지 못하고 있습니다.&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9343079148</id>
#  <title>스쿼트 미션</title>
#  <content type="text">안녕하세요
#  지난번에 무료체험으로 스쿼트 미션 했을때 너무 좋아서 유료구독을 했는데 스쿼트를 아무리 열심히 해도 숫자가 안 줄어드네요...무료체험 할때는 한번도 이런적이 없었는데 왜이럴까요ㅠ 그때랑 똑같이 설명대로 스쿼트하는데 인식이 되지가 않습니다 어플 지웠다 다시 깔았는데도 똑같아요
#  꼭 답변 부탁드려요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>4</im:rating>
#  <updated>2022-11-29T14:40:23-07:00</updated>
#  <im:version>6.73.3</im:version>
#  <author><name>빵댕댕댕</name><uri>https://itunes.apple.com/kr/reviews/id727562172</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;스쿼트 미션&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
# ...
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9313866531</id>
#  <title>선천적 잠탱이에게 필수</title>
#  <content type="text">만약 잠을 나눌 수 았다면 얼마나 좋을까요?? 저처럼 잠이 많은 사람들은 잠을 잘 못 자는 불면증이 았는 사람들이게 잠을 나누어 준다면 서로 윈윈인 상황으로 흘려가겠죠? 너무나 많은 잠을 요구한다면 문제가 되겠지만요 어쨌든 제가 하고 싶은 말은 정말 좋은 앱이예요! 유료 결제의 필요성을 아직 느끼지 못하서 무료로 사용하고 있어요 원래는 잠귀가 너무 어두워서 알람을 10분 간격으로 8개씩 맞춰도 늦게 일어나서 맨날 택시 타고 등교했는데요, 이 앱을 사용하고 나서 첫날부터 사이렌 알람소리로 깨서 느긋하게 아침 준비를 할 수 있었어요 제가 사이렌 소리를 좀 무서워하는 편이고 잠 자다가도 사이렌 소리가 나면 벌떡 깼어서 정말 효과적이였어요! 사이렌 소리 말고도 잔잔한 노래들과 자극적인 소리 등 다양한 소리가 많아서 사이렌 소리에 둔감해질 때 다른 소리로 바꿀 수 있는 점이 좋았어요 원래는 수학문제 10문제 푸는 것으로 설정했는데 제가 깨서 문제를 풀어도 다시 눈을 감더라고요 정말 눈만 감은 건데 1시간 반이 훌쩍 지나더라구요 😓 그래서 오늘부터는 사진 찍기 기능을 사용해보려고 해요 효과가 정말 좋을 것 같아요 이렇게 삶을 윤택하게 해주는 앱을 만들어 주셔서 정말 감사합니다 😊</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-11-21T08:42:02-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>쏙쏙뽁</name><uri>https://itunes.apple.com/kr/reviews/id196673366</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;선천적 잠탱이에게 필수&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;만약 잠을 나눌 수 았다면 얼마나 좋을까요?? 저처럼 잠이 많은 사람들은 잠을 잘 못 자는 불면증이 았는 사람들이게 잠을 나누어 준다면 서로 윈윈인 상황으로 흘려가겠죠? 너무나 많은 잠을 요구한다면 문제가 되겠지만요 어쨌든 제가 하고 싶은 말은 정말 좋은 앱이예요! 유료 결제의 필요성을 아직 느끼지 못하서 무료로 사용하고 있어요 원래는 잠귀가 너무 어두워서 알람을 10분 간격으로 8개씩 맞춰도 늦게 일어나서 맨날 택시 타고 등교했는데요, 이 앱을 사용하고 나서 첫날부터 사이렌 알람소리로 깨서 느긋하게 아침 준비를 할 수 있었어요 제가 사이렌 소리를 좀 무서워하는 편이고 잠 자다가도 사이렌 소리가 나면 벌떡 깼어서 정말 효과적이였어요! 사이렌 소리 말고도 잔잔한 노래들과 자극적인 소리 등 다양한 소리가 많아서 사이렌 소리에 둔감해질 때 다른 소리로 바꿀 수 있는 점이 좋았어요 원래는 수학문제 10문제 푸는 것으로 설정했는데 제가 깨서 문제를 풀어도 다시 눈을 감더라고요 정말 눈만 감은 건데 1시간 반이 훌쩍 지나더라구요 😓 그래서 오늘부터는 사진 찍기 기능을 사용해보려고 해요 효과가 정말 좋을 것 같아요 이렇게 삶을 윤택하게 해주는 앱을 만들어 주셔서 정말 감사합니다 😊&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9313713337</id>
#  <title>언어 변경 문의요</title>
#  <content type="text">지금까지 한글로 제대로 나왔는데 어느순간 영문만 나오네요..
#
#  언어 변경 경로좀요. ㅠ</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-11-21T07:48:22-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>파란유성매직</name><uri>https://itunes.apple.com/kr/reviews/id487244848</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;언어 변경 문의요&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;지금까지 한글로 제대로 나왔는데 어느순간 영문만 나오네요..&lt;br/&gt;&lt;br/&gt;언어 변경 경로좀요. ㅠ&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9312594376</id>
#  <title>알라미 유료결제</title>
#  <content type="text">알라미 유료결제버튼 누른 적도 유료서비스를 이용한 적도 없습니다 하지만 오늘 아침 7:28분 제 통장에서 돈이 빠져나갔습니다 어찌된 연유인지 알고 싶지만 어디를 통해 이문제를 해결해야할 지 모르겠습니다 이글을 보신다면 연락부탁드립니다</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-11-21T00:50:21-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>regén</name><uri>https://itunes.apple.com/kr/reviews/id1377613159</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알라미 유료결제&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;알라미 유료결제버튼 누른 적도 유료서비스를 이용한 적도 없습니다 하지만 오늘 아침 7:28분 제 통장에서 돈이 빠져나갔습니다 어찌된 연유인지 알고 싶지만 어디를 통해 이문제를 해결해야할 지 모르겠습니다 이글을 보신다면 연락부탁드립니다&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9310533647</id>
#  <title>광고 필터링 부탁..</title>
#  <content type="text">광고가 ; 뭔 야웹툰 광고가 나오는데 이게 맞나요? 미성년자도 쓸 수 있는 어플인데 "너무 커서 안 들어가잖아 부끄러우니까 뒤에서 박아 주는 게 좋은 것 같아"라는 문구가 나오는데 시정부탁드립니다..
#
#  심지어 이거 의견 보내기류 하려는데 키보드 내려가는 버튼이 없게 인터페이스가 설정되어 있어서 ㅋㅋㅋㅋ 내용 다 써놨는데 다음을 못눌러서 여기다 씁니다 ㅋㅋ 잘 쓰고 있는데 갑자기 저 광고가 너무 불쾌해요</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>3</im:rating>
#  <updated>2022-11-20T09:35:41-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>dnduddlEhdro</name><uri>https://itunes.apple.com/kr/reviews/id420597179</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;광고 필터링 부탁..&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;광고가 ; 뭔 야웹툰 광고가 나오는데 이게 맞나요? 미성년자도 쓸 수 있는 어플인데 &amp;#34;너무 커서 안 들어가잖아 부끄러우니까 뒤에서 박아 주는 게 좋은 것 같아&amp;#34;라는 문구가 나오는데 시정부탁드립니다..&lt;br/&gt;&lt;br/&gt;심지어 이거 의견 보내기류 하려는데 키보드 내려가는 버튼이 없게 인터페이스가 설정되어 있어서 ㅋㅋㅋㅋ 내용 다 써놨는데 다음을 못눌러서 여기다 씁니다 ㅋㅋ 잘 쓰고 있는데 갑자기 저 광고가 너무 불쾌해요&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9307365500</id>
#  <title>알람이 안울림</title>
#  <content type="text">지금까지 계속 그랬음 이번에는 그냥 폰을 꺼버리더라고...? 배터리 53프로에 충전까지하고잤는데 말이됨? 시험 얼마 안남았는데 잠깐 잔 게 아니라 존나자서 큰일남</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>1</im:rating>
#  <updated>2022-11-19T15:15:30-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>ㅓ무느너얼엍</name><uri>https://itunes.apple.com/kr/reviews/id1463471024</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;알람이 안울림&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;지금까지 계속 그랬음 이번에는 그냥 폰을 꺼버리더라고...? 배터리 53프로에 충전까지하고잤는데 말이됨? 시험 얼마 안남았는데 잠깐 잔 게 아니라 존나자서 큰일남&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9306308472</id>
#  <title>무조건 일어날 수 있는 알림앱인듯</title>
#  <content type="text">랜덤 알림음도 있어서 다 좋은데 혹시 언어를 어떻게 바꾸나요 ㅠㅠㅠㅠㅠ 아예 모르는 언어로 바뀌어서 못바꾸고있어요….</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-11-19T08:11:47-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>이 점만 고쳐주세요!</name><uri>https://itunes.apple.com/kr/reviews/id618361250</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;무조건 일어날 수 있는 알림앱인듯&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;랜덤 알림음도 있어서 다 좋은데 혹시 언어를 어떻게 바꾸나요 ㅠㅠㅠㅠㅠ 아예 모르는 언어로 바뀌어서 못바꾸고있어요….&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>,
#  <entry>
#  <id>9305847190</id>
#  <title>삭제반복중..</title>
#  <content type="text">매일 알람을 끄지 않고 앱 삭제를 해서 늦잠을 잡니다… 깔았다 지웠다를 계속 반복중입니다…
#  구독 결제를 해도 소용이 없더군요…….
#  삭제 방지가 아이폰에선 되지 않는건가요……
#  알람때문에 삼성폰을 써야하나 고민중임니다……</content>
#  <im:contenttype label="앱" term="Application"></im:contenttype>
#  <im:votesum>0</im:votesum>
#  <im:votecount>0</im:votecount>
#  <im:rating>5</im:rating>
#  <updated>2022-11-19T05:53:41-07:00</updated>
#  <im:version>6.73.2</im:version>
#  <author><name>난 너무 기여우어어어에엥이</name><uri>https://itunes.apple.com/kr/reviews/id1159271779</uri></author>
#  <link href="https://itunes.apple.com/kr/review?id=1163786766&amp;type=Purple%20Software" rel="related"/>
#  <content type="html">&lt;table border="0" width="100%"&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#              &lt;table border="0" width="100%" cellspacing="0" cellpadding="0"&gt;
#                  &lt;tr valign="top" align="left"&gt;
#
#
#                      	&lt;td width="100%"&gt;
#
#                          &lt;b&gt;&lt;a href="https://apps.apple.com/kr/app/%EC%95%8C%EB%9D%BC%EB%AF%B8-%EC%83%81%EC%BE%8C%ED%95%9C-%EC%95%84%EC%B9%A8%EC%9D%84-%EC%9C%84%ED%95%9C-%EC%95%8C%EB%9E%8C%EC%8B%9C%EA%B3%84-%EC%88%98%EB%A9%B4-%EC%82%AC%EC%9A%B4%EB%93%9C/id1163786766?uo=2"&gt;삭제반복중..&lt;/a&gt;&lt;/b&gt;&lt;br/&gt;
#
#
#
#
#
#
#
#                         &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;
#
#                          &lt;/font&gt;
#                      &lt;/td&gt;
#                  &lt;/tr&gt;
#              &lt;/table&gt;
#          &lt;/td&gt;
#      &lt;/tr&gt;
#      &lt;tr&gt;
#          &lt;td&gt;
#
#                  &lt;font size="2" face="Helvetica,Arial,Geneva,Swiss,SunSans-Regular"&gt;&lt;br/&gt;매일 알람을 끄지 않고 앱 삭제를 해서 늦잠을 잡니다… 깔았다 지웠다를 계속 반복중입니다…&lt;br/&gt;구독 결제를 해도 소용이 없더군요…….&lt;br/&gt;삭제 방지가 아이폰에선 되지 않는건가요……&lt;br/&gt;알람때문에 삼성폰을 써야하나 고민중임니다……&lt;/font&gt;&lt;br/&gt;
#
#
#
#          &lt;/td&gt;
#      &lt;/tr&gt;
#  &lt;/table&gt;
#  </content>
#  </entry>]

# %%
# 필요한 요소 추출

<title>좋습니다</title>
<content type="text">정말 짜증나게해서 일어나기 좋습니다 ㅎㅎ</content>
<im:rating>5</im:rating>
<updated>2022-12-17T11:58:05-07:00</updated>
<im:version>6.75.0</im:version>
<author><name>인천송도</name>

# %%
# 

country = 'us'
app_id = '1163786766'
app_name = 'alarmy' # 아무거나 입력해도 됨
last_page = 10
file_name = f'scrap_apple_{app_name}_{country}.csv'

# 한국 : kr
# 미국 : us
# 국가코드는 https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2

# %%
def scrapping_alarmy_apple(page_num, app_id, country):
    from bs4 import BeautifulSoup
    import urllib.request
    url_start = f'https://itunes.apple.com/{country}/rss/customerreviews/page='
    url_end = f'/id={app_id}/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1163786766/sortBy=mostRecent/xml'
    html = urllib.request.urlopen(url_start + str(page_num) + url_end)
    soup = BeautifulSoup(html, 'html.parser')
    
    soups = soup.find_all('entry')
    
    title = []
    content = []
    rating = []
    date = []
    version = []
    name = []
    
    for soup in soups:
        try:
            title.append(soup.find('title').string)
        except:
            title.append('None')
        try:
            content.append(soup.find('content', attrs={'type':'text'}).string)
        except:
            content.append('None')
        try:
            rating.append(soup.find('im:rating').string)
        except:
            rating.append('None')
        try:
            date.append(soup.find('updated').string)
        except:
            date.append('None')
        try:
            version.append(soup.find('im:version').string)
        except:
            version.append('None')
        try:
            name.append(soup.find('name').string)
        except:
            name.append('None')
    
    return title, content, rating, date, version, name

# %%
ls_title = []
ls_content = []
ls_rating = []
ls_date = []
ls_version = []
ls_name = []

for i in range(1, last_page + 1):
    title, content, rating, date, version, name = scrapping_alarmy_apple(i, app_id, country)
    
    ls_title.append(title)
    ls_content.append(content)
    ls_rating.append(rating)
    ls_date.append(date)
    ls_version.append(version)
    ls_name.append(name)

title = [ x.string for comps in ls_title for x in comps ]
content = [ x.string for comps in ls_content for x in comps ]
rating = [ x.string for comps in ls_rating for x in comps ]
date = [ x.string for comps in ls_date for x in comps ]
version = [ x.string for comps in ls_version for x in comps ]
name = [ x.string for comps in ls_name for x in comps ]

# %%
import pandas as pd

df = pd.DataFrame([title, content, rating, date, version, name]).T
df.columns = ['title', 'content', 'rating', 'date', 'version', 'author']
df.to_csv(file_name)
