# %%
# 야생동물 데이터 다운로드
# https://aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=realm&dataSetSn=645

# COCO 데이터셋
# https://public.roboflow.com/object-detection/microsoft-coco-subset

# %%
import json
import shutil
import os 
import yaml
import cv2
import zipfile
import time
from glob import glob
from tqdm import tqdm
from openpyxl import Workbook
from scipy.sparse import data
from sklearn.model_selection import train_test_split

# %%
# 종혁 : 코랩 실행시
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 이미지 리사이징 처리한 야생동물 데이터불러오기
#
# 대상 야생동물 : 고라니, 멧돼지, 너구리, 반달가슴곰

# %%
# 압축 파일 경로를 설정해주세요.
# 리스트 형태이며, 여러 파일도 가능합니다.
zip_file_path_image =  ['/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/원천데이터/TS_01.고라니_리사이징완료.zip',
                       '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/원천데이터/TS_02.멧돼지_리사이징완료.zip',
                       '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/원천데이터/TS_03.너구리_리사이징완료.zip',
                       '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/원천데이터/TS_06.반달가슴곰_리사이징완료.zip']

zip_file_path_json = ['/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/라벨링데이터/TL_01.고라니.zip',
                      '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/라벨링데이터/TL_02.멧돼지.zip',
                      '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/라벨링데이터/TL_03.너구리.zip',
                      '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/1.Training/라벨링데이터/TL_06.반달가슴곰.zip']
                      

# 본 Main 코드 폴더가 있는 폴더 경로를 지정해주세요.
# 압축이 풀린"이미지" 파일은 Main 코드가 있는 폴더 -> Dataset -> images 폴더로 들어갑니다.
# 압축이 풀린"json" 파일은 Main 코드가 있는 폴더 -> Dataset -> json 폴더로 들어갑니다.
# !mkdir /content/train
# !mkdir /content/train/Dataset
# !mkdir /content/train/Dataset/images
# !mkdir /content/train/Dataset/json_day_night
# !mkdir /content/train/Dataset/labels

main_path = '/content/train/'
google_drive_path = '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/코드/03. yolov7_train/'

# %%
for i in tqdm(range(len(zip_file_path_image))):
  zip_file_image = zipfile.ZipFile(zip_file_path_image[i])
  file_list = zip_file_image.namelist()
  for file_name in tqdm(file_list, desc=f'Extracting files ({i}/{2*len(zip_file_path_image)}'):
    zip_file_image.extract(file_name, main_path + 'Dataset/images')

  zip_file_json = zipfile.ZipFile(zip_file_path_json[i])
  file_list = zip_file_json.namelist()
  for file_name in tqdm(file_list, desc = f'Extracting files ({i}/{2*len(zip_file_path_image)}'):
    zip_file_json.extract(file_name, main_path + 'Dataset/json_day_night')
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Extracting files (0/8:   0%|          | 0/31074 [00:00<?, ?it/s]
# Extracting files (0/8:   0%|          | 1/31074 [00:00<5:11:35,  1.66it/s]
# Extracting files (0/8:   0%|          | 96/31074 [00:00<04:10, 123.78it/s]
# Extracting files (0/8:   1%|          | 204/31074 [00:01<01:53, 272.84it/s]
# Extracting files (0/8:   1%|▏         | 394/31074 [00:01<00:53, 569.07it/s]
# Extracting files (0/8:   2%|▏         | 571/31074 [00:01<00:37, 815.37it/s]
# Extracting files (0/8:   2%|▏         | 741/31074 [00:01<00:29, 1016.41it/s]
# Extracting files (0/8:   3%|▎         | 1004/31074 [00:01<00:21, 1411.50it/s]
# Extracting files (0/8:   4%|▍         | 1189/31074 [00:01<00:25, 1193.82it/s]
# Extracting files (0/8:  81%|████████  | 25095/31074 [00:30<00:08, 702.52it/s]
# Extracting files (0/8:  81%|████████  | 25215/31074 [00:30<00:06, 840.18it/s]
# Extracting files (0/8:  82%|████████▏ | 25360/31074 [00:30<00:05, 1012.20it/s]
# Extracting files (0/8:  82%|████████▏ | 25465/31074 [00:30<00:05, 982.42it/s]
# Extracting files (0/8:  82%|████████▏ | 25566/31074 [00:30<00:06, 900.52it/s]
# Extracting files (0/8:  83%|████████▎ | 25689/31074 [00:30<00:05, 989.09it/s]
# Extracting files (0/8:  83%|████████▎ | 25806/31074 [00:31<00:05, 1038.34it/s]
# Extracting files (0/8:  84%|████████▎ | 25991/31074 [00:31<00:04, 1266.27it/s]
# Extracting files (0/8:  84%|████████▍ | 26121/31074 [00:31<00:06, 783.84it/s]
# Extracting files (0/8:  84%|████████▍ | 26224/31074 [00:31<00:05, 809.26it/s]
# Extracting files (0/8:  85%|████████▍ | 26358/31074 [00:31<00:05, 924.90it/s]
# Extracting files (0/8:  85%|████████▌ | 26468/31074 [00:31<00:05, 878.83it/s]
# Extracting files (0/8:  86%|████████▌ | 26577/31074 [00:31<00:04, 928.34it/s]
# Extracting files (0/8:  86%|████████▋ | 26804/31074 [00:32<00:03, 1265.99it/s]
# Extracting files (0/8:  87%|████████▋ | 26957/31074 [00:32<00:03, 1333.82it/s]
# Extracting files (0/8:  87%|████████▋ | 27130/31074 [00:32<00:02, 1392.03it/s]
# Extracting files (0/8:  88%|████████▊ | 27277/31074 [00:32<00:07, 540.35it/s]
# Extracting files (0/8:  88%|████████▊ | 27418/31074 [00:33<00:05, 653.55it/s]
# Extracting files (0/8:  89%|████████▊ | 27537/31074 [00:33<00:05, 706.61it/s]
# Extracting files (0/8:  89%|████████▉ | 27648/31074 [00:33<00:04, 770.37it/s]
# Extracting files (0/8:  89%|████████▉ | 27773/31074 [00:33<00:03, 866.06it/s]
# Extracting files (0/8:  90%|████████▉ | 27887/31074 [00:33<00:03, 858.08it/s]
# Extracting files (0/8:  90%|█████████ | 28064/31074 [00:33<00:02, 1064.05it/s]
# Extracting files (0/8:  91%|█████████ | 28233/31074 [00:33<00:02, 1214.70it/s]
# Extracting files (0/8:  92%|█████████▏| 28472/31074 [00:33<00:01, 1518.34it/s]
# Extracting files (0/8:  92%|█████████▏| 28733/31074 [00:33<00:01, 1811.32it/s]
# Extracting files (0/8:  93%|█████████▎| 28930/31074 [00:34<00:01, 1722.22it/s]
# Extracting files (0/8:  94%|█████████▎| 29114/31074 [00:34<00:01, 1463.91it/s]
# Extracting files (0/8:  94%|█████████▍| 29275/31074 [00:34<00:01, 1283.67it/s]
# Extracting files (0/8:  95%|█████████▍| 29425/31074 [00:34<00:01, 1332.83it/s]
# Extracting files (0/8:  95%|█████████▌| 29569/31074 [00:34<00:01, 1275.51it/s]
# Extracting files (0/8:  96%|█████████▌| 29704/31074 [00:34<00:01, 1206.11it/s]
# Extracting files (0/8:  96%|█████████▌| 29856/31074 [00:34<00:00, 1283.36it/s]
# Extracting files (0/8:  97%|█████████▋| 30008/31074 [00:34<00:00, 1344.10it/s]
# Extracting files (0/8:  97%|█████████▋| 30147/31074 [00:35<00:00, 1346.69it/s]
# Extracting files (0/8:  97%|█████████▋| 30285/31074 [00:35<00:00, 1144.19it/s]
# Extracting files (0/8:  98%|█████████▊| 30407/31074 [00:35<00:01, 620.88it/s]
# Extracting files (0/8:  98%|█████████▊| 30592/31074 [00:35<00:00, 818.15it/s]
# Extracting files (0/8:  99%|█████████▉| 30770/31074 [00:35<00:00, 997.12it/s]
# Extracting files (0/8: 100%|██████████| 31074/31074 [00:36<00:00, 861.01it/s]
#
# Extracting files (0/8:   0%|          | 0/31074 [00:00<?, ?it/s]
# Extracting files (0/8:   0%|          | 1/31074 [00:00<5:09:21,  1.67it/s]
# Extracting files (0/8:   2%|▏         | 676/31074 [00:00<00:23, 1303.90it/s]
# Extracting files (0/8:   4%|▍         | 1363/31074 [00:00<00:11, 2505.76it/s]
# Extracting files (0/8:   7%|▋         | 2039/31074 [00:00<00:08, 3508.87it/s]
# Extracting files (0/8:   8%|▊         | 2626/31074 [00:01<00:07, 3742.69it/s]
# Extracting files (0/8:  10%|█         | 3155/31074 [00:01<00:08, 3484.18it/s]
# Extracting files (0/8:  12%|█▏        | 3628/31074 [00:01<00:07, 3753.69it/s]
# Extracting files (0/8:  14%|█▍        | 4351/31074 [00:01<00:05, 4609.69it/s]
# Extracting files (0/8:  17%|█▋        | 5153/31074 [00:01<00:04, 5496.33it/s]
# Extracting files (0/8:  19%|█▉        | 5941/31074 [00:01<00:04, 6141.71it/s]
# Extracting files (0/8:  22%|██▏       | 6685/31074 [00:01<00:03, 6502.42it/s]
# Extracting files (0/8:  24%|██▎       | 7380/31074 [00:01<00:03, 6523.66it/s]
# Extracting files (0/8:  26%|██▌       | 8064/31074 [00:01<00:03, 6609.78it/s]
# Extracting files (0/8:  28%|██▊       | 8748/31074 [00:02<00:03, 6572.68it/s]
# Extracting files (0/8:  31%|███       | 9520/31074 [00:02<00:03, 6904.57it/s]
# Extracting files (0/8:  33%|███▎      | 10270/31074 [00:02<00:02, 7078.25it/s]
# Extracting files (0/8:  35%|███▌      | 10987/31074 [00:02<00:02, 7025.39it/s]
# Extracting files (0/8:  38%|███▊      | 11784/31074 [00:02<00:02, 7301.13it/s]
# Extracting files (0/8:  41%|████      | 12602/31074 [00:02<00:02, 7560.39it/s]
# Extracting files (0/8:  43%|████▎     | 13434/31074 [00:02<00:02, 7784.27it/s]
# Extracting files (0/8:  46%|████▌     | 14216/31074 [00:02<00:02, 7771.06it/s]
# Extracting files (0/8:  48%|████▊     | 15028/31074 [00:02<00:02, 7869.78it/s]
# Extracting files (0/8:  51%|█████     | 15817/31074 [00:02<00:01, 7851.70it/s]
# Extracting files (0/8:  53%|█████▎    | 16604/31074 [00:03<00:01, 7799.05it/s]
# Extracting files (0/8:  56%|█████▌    | 17413/31074 [00:03<00:01, 7883.98it/s]
# Extracting files (0/8:  59%|█████▊    | 18203/31074 [00:03<00:01, 7807.81it/s]
# Extracting files (0/8:  61%|██████▏   | 19045/31074 [00:03<00:01, 7988.66it/s]
# Extracting files (0/8:  64%|██████▍   | 19845/31074 [00:03<00:01, 7653.89it/s]
# Extracting files (0/8:  66%|██████▋   | 20638/31074 [00:03<00:01, 7732.93it/s]
# Extracting files (0/8:  69%|██████▉   | 21478/31074 [00:03<00:01, 7925.55it/s]
# Extracting files (0/8:  72%|███████▏  | 22273/31074 [00:03<00:01, 7067.77it/s]
# Extracting files (0/8:  74%|███████▍  | 23057/31074 [00:03<00:01, 7277.26it/s]
# Extracting files (0/8:  77%|███████▋  | 23800/31074 [00:03<00:01, 7258.89it/s]
# Extracting files (0/8:  79%|███████▉  | 24537/31074 [00:04<00:01, 6046.65it/s]
# Extracting files (0/8:  81%|████████  | 25181/31074 [00:04<00:01, 5345.98it/s]
# Extracting files (0/8:  83%|████████▎ | 25753/31074 [00:04<00:01, 4621.11it/s]
# Extracting files (0/8:  84%|████████▍ | 26252/31074 [00:05<00:02, 2196.02it/s]
# Extracting files (0/8:  87%|████████▋ | 27048/31074 [00:05<00:01, 2946.69it/s]
# Extracting files (0/8:  90%|████████▉ | 27898/31074 [00:05<00:00, 3817.88it/s]
# Extracting files (0/8:  92%|█████████▏| 28668/31074 [00:05<00:00, 4527.29it/s]
# Extracting files (0/8:  94%|█████████▍| 29323/31074 [00:05<00:00, 4457.69it/s]
# Extracting files (0/8:  97%|█████████▋| 30098/31074 [00:05<00:00, 5149.85it/s]
# Extracting files (0/8: 100%|██████████| 31074/31074 [00:05<00:00, 5352.25it/s]
#  25%|██▌       | 1/4 [00:47<02:22, 47.40s/it]
# Extracting files (1/8:   0%|          | 0/30700 [00:00<?, ?it/s]
# Extracting files (1/8:   0%|          | 1/30700 [00:00<4:27:15,  1.91it/s]
# Extracting files (1/8:   0%|          | 87/30700 [00:00<03:44, 136.26it/s]
# Extracting files (1/8:   1%|          | 181/30700 [00:00<02:03, 248.00it/s]
# Extracting files (1/8:   1%|          | 297/30700 [00:01<01:12, 417.90it/s]
# Extracting files (1/8:   1%|▏         | 460/30700 [00:01<00:44, 672.48it/s]
# Extracting files (1/8:   2%|▏         | 586/30700 [00:01<00:37, 807.54it/s]
# Extracting files (1/8:   3%|▎         | 808/30700 [00:01<00:25, 1156.50it/s]
# Extracting files (1/8:   3%|▎         | 954/30700 [00:01<00:30, 980.08it/s]
# Extracting files (1/8:   4%|▍         | 1179/30700 [00:01<00:23, 1269.67it/s]
# Extracting files (1/8:   4%|▍         | 1335/30700 [00:01<00:21, 1338.48it/s]
# Extracting files (1/8:   5%|▍         | 1490/30700 [00:02<00:29, 982.14it/s]
# Extracting files (1/8:   5%|▌         | 1647/30700 [00:02<00:26, 1103.65it/s]
# Extracting files (1/8:   6%|▌         | 1795/30700 [00:02<00:24, 1179.34it/s]
# Extracting files (1/8:   6%|▋         | 1936/30700 [00:02<00:23, 1233.87it/s]
# Extracting files (1/8:   7%|▋         | 2075/30700 [00:03<01:02, 457.01it/s]
# Extracting files (1/8:   7%|▋         | 2177/30700 [00:03<00:54, 520.22it/s]
# Extracting files (1/8:   7%|▋         | 2279/30700 [00:03<00:48, 591.12it/s]
# Extracting files (1/8:   8%|▊         | 2380/30700 [00:03<00:52, 534.80it/s]
# Extracting files (1/8:   8%|▊         | 2464/30700 [00:03<00:51, 551.10it/s]
# Extracting files (1/8:   8%|▊         | 2541/30700 [00:03<00:55, 505.54it/s]
# Extracting files (1/8:   9%|▊         | 2649/30700 [00:04<00:46, 609.19it/s]
# Extracting files (1/8:   9%|▉         | 2728/30700 [00:04<00:45, 610.28it/s]
# Extracting files (1/8:   9%|▉         | 2802/30700 [00:04<00:47, 585.40it/s]
# Extracting files (1/8:   9%|▉         | 2887/30700 [00:04<00:43, 643.31it/s]
# Extracting files (1/8:  10%|▉         | 2990/30700 [00:04<00:37, 736.00it/s]
# Extracting files (1/8:  10%|█         | 3128/30700 [00:04<00:30, 899.34it/s]
# Extracting files (1/8:  11%|█         | 3227/30700 [00:04<00:30, 908.25it/s]
# Extracting files (1/8:  11%|█         | 3324/30700 [00:04<00:36, 749.56it/s]
# Extracting files (1/8:  11%|█         | 3408/30700 [00:04<00:37, 737.34it/s]
# Extracting files (1/8:  11%|█▏        | 3488/30700 [00:05<00:49, 547.99it/s]
# Extracting files (1/8:  12%|█▏        | 3554/30700 [00:05<00:52, 521.75it/s]
# Extracting files (1/8:  12%|█▏        | 3663/30700 [00:05<00:42, 640.61it/s]
# Extracting files (1/8:  12%|█▏        | 3739/30700 [00:05<00:40, 667.19it/s]
# Extracting files (1/8:  12%|█▏        | 3814/30700 [00:05<00:41, 649.09it/s]
# Extracting files (1/8:  13%|█▎        | 3909/30700 [00:05<00:37, 723.52it/s]
# Extracting files (1/8:  13%|█▎        | 3987/30700 [00:05<00:36, 723.10it/s]
# Extracting files (1/8:  13%|█▎        | 4063/30700 [00:06<00:40, 662.14it/s]
# Extracting files (1/8:  14%|█▎        | 4171/30700 [00:06<00:34, 769.64it/s]
# Extracting files (1/8:  14%|█▍        | 4252/30700 [00:06<00:38, 695.53it/s]
# Extracting files (1/8:  14%|█▍        | 4326/30700 [00:06<00:38, 685.02it/s]
# Extracting files (1/8:  14%|█▍        | 4398/30700 [00:06<00:44, 594.20it/s]
# Extracting files (1/8:  15%|█▍        | 4487/30700 [00:06<00:39, 665.74it/s]
# Extracting files (1/8:  15%|█▍        | 4572/30700 [00:06<00:36, 712.16it/s]
# Extracting files (1/8:  15%|█▌        | 4682/30700 [00:06<00:31, 815.02it/s]
# Extracting files (1/8:  16%|█▌        | 4768/30700 [00:07<00:34, 753.88it/s]
# Extracting files (1/8:  16%|█▌        | 4847/30700 [00:07<00:44, 583.15it/s]
# Extracting files (1/8:  16%|█▌        | 4914/30700 [00:07<00:49, 516.70it/s]
# Extracting files (1/8:  17%|█▋        | 5112/30700 [00:07<00:31, 820.79it/s]
# Extracting files (1/8:  17%|█▋        | 5220/30700 [00:07<00:28, 879.74it/s]
# Extracting files (1/8:  18%|█▊        | 5435/30700 [00:07<00:21, 1194.64it/s]
# Extracting files (1/8:  18%|█▊        | 5642/30700 [00:07<00:17, 1423.44it/s]
# Extracting files (1/8:  19%|█▉        | 5798/30700 [00:07<00:18, 1369.19it/s]
# Extracting files (1/8:  19%|█▉        | 5980/30700 [00:08<00:16, 1489.09it/s]
# Extracting files (1/8:  20%|██        | 6192/30700 [00:08<00:14, 1662.73it/s]
# Extracting files (1/8:  21%|██        | 6390/30700 [00:08<00:13, 1748.92it/s]
# Extracting files (1/8:  22%|██▏       | 6608/30700 [00:08<00:12, 1872.50it/s]
# Extracting files (1/8:  22%|██▏       | 6800/30700 [00:08<00:13, 1784.57it/s]
# Extracting files (1/8:  23%|██▎       | 6984/30700 [00:08<00:13, 1798.33it/s]
# Extracting files (1/8:  23%|██▎       | 7176/30700 [00:08<00:12, 1832.68it/s]
# Extracting files (1/8:  24%|██▍       | 7362/30700 [00:08<00:12, 1828.43it/s]
# Extracting files (1/8:  25%|██▍       | 7557/30700 [00:08<00:12, 1863.52it/s]
# Extracting files (1/8:  25%|██▌       | 7745/30700 [00:09<00:15, 1469.57it/s]
# Extracting files (1/8:  26%|██▌       | 7929/30700 [00:09<00:14, 1545.67it/s]
# Extracting files (1/8:  27%|██▋       | 8158/30700 [00:09<00:12, 1738.39it/s]
# Extracting files (1/8:  27%|██▋       | 8362/30700 [00:09<00:12, 1817.94it/s]
# Extracting files (1/8:  28%|██▊       | 8552/30700 [00:09<00:13, 1662.13it/s]
# Extracting files (1/8:  28%|██▊       | 8727/30700 [00:09<00:15, 1447.75it/s]
# Extracting files (1/8:  29%|██▉       | 8882/30700 [00:09<00:17, 1217.74it/s]
# Extracting files (1/8:  29%|██▉       | 9025/30700 [00:09<00:17, 1227.31it/s]
# Extracting files (1/8:  30%|██▉       | 9156/30700 [00:10<00:18, 1154.41it/s]
# Extracting files (1/8:  30%|███       | 9300/30700 [00:10<00:17, 1222.33it/s]
# Extracting files (1/8:  31%|███       | 9507/30700 [00:10<00:14, 1437.24it/s]
# Extracting files (1/8:  31%|███▏      | 9666/30700 [00:10<00:14, 1476.98it/s]
# Extracting files (1/8:  32%|███▏      | 9820/30700 [00:10<00:18, 1139.33it/s]
# Extracting files (1/8:  33%|███▎      | 10023/30700 [00:10<00:15, 1344.42it/s]
# Extracting files (1/8:  33%|███▎      | 10175/30700 [00:10<00:17, 1167.19it/s]
# Extracting files (1/8:  34%|███▎      | 10320/30700 [00:10<00:16, 1231.28it/s]
# Extracting files (1/8:  34%|███▍      | 10487/30700 [00:11<00:15, 1339.06it/s]
# Extracting files (1/8:  35%|███▍      | 10632/30700 [00:11<00:17, 1178.92it/s]
# Extracting files (1/8:  35%|███▌      | 10791/30700 [00:11<00:15, 1278.04it/s]
# Extracting files (1/8:  36%|███▌      | 10935/30700 [00:11<00:14, 1319.66it/s]
# Extracting files (1/8:  36%|███▌      | 11075/30700 [00:11<00:15, 1243.80it/s]
# Extracting files (1/8:  37%|███▋      | 11227/30700 [00:11<00:14, 1314.26it/s]
# Extracting files (1/8:  37%|███▋      | 11364/30700 [00:11<00:14, 1318.81it/s]
# Extracting files (1/8:  37%|███▋      | 11500/30700 [00:11<00:14, 1328.76it/s]
# Extracting files (1/8:  38%|███▊      | 11636/30700 [00:12<00:14, 1279.95it/s]
# Extracting files (1/8:  38%|███▊      | 11767/30700 [00:12<00:18, 1049.75it/s]
# Extracting files (1/8:  39%|███▉      | 11916/30700 [00:12<00:16, 1157.05it/s]
# Extracting files (1/8:  39%|███▉      | 12064/30700 [00:12<00:24, 761.59it/s]
# Extracting files (1/8:  40%|███▉      | 12276/30700 [00:12<00:18, 1013.48it/s]
# Extracting files (1/8:  41%|████      | 12475/30700 [00:12<00:15, 1214.36it/s]
# Extracting files (1/8:  41%|████      | 12628/30700 [00:13<00:18, 998.41it/s]
# Extracting files (1/8:  42%|████▏     | 12755/30700 [00:13<00:19, 927.03it/s]
# Extracting files (1/8:  42%|████▏     | 12941/30700 [00:13<00:15, 1113.01it/s]
# Extracting files (1/8:  43%|████▎     | 13074/30700 [00:13<00:15, 1139.17it/s]
# Extracting files (1/8:  43%|████▎     | 13262/30700 [00:13<00:13, 1315.90it/s]
# Extracting files (1/8:  44%|████▎     | 13410/30700 [00:13<00:16, 1074.16it/s]
# Extracting files (1/8:  44%|████▍     | 13535/30700 [00:13<00:16, 1065.17it/s]
# Extracting files (1/8:  45%|████▍     | 13716/30700 [00:13<00:13, 1239.28it/s]
# Extracting files (1/8:  45%|████▌     | 13854/30700 [00:14<00:13, 1270.10it/s]
# Extracting files (1/8:  46%|████▌     | 13991/30700 [00:14<00:15, 1065.64it/s]
# Extracting files (1/8:  46%|████▌     | 14132/30700 [00:14<00:14, 1145.33it/s]
# Extracting files (1/8:  46%|████▋     | 14257/30700 [00:14<00:14, 1111.49it/s]
# Extracting files (1/8:  47%|████▋     | 14405/30700 [00:14<00:13, 1204.28it/s]
# Extracting files (1/8:  48%|████▊     | 14590/30700 [00:14<00:11, 1375.59it/s]
# Extracting files (1/8:  48%|████▊     | 14735/30700 [00:14<00:16, 939.37it/s]
# Extracting files (1/8:  49%|████▉     | 14969/30700 [00:15<00:12, 1231.66it/s]
# Extracting files (1/8:  50%|████▉     | 15204/30700 [00:15<00:10, 1487.75it/s]
# Extracting files (1/8:  50%|█████     | 15446/30700 [00:15<00:08, 1717.43it/s]
# Extracting files (1/8:  51%|█████     | 15678/30700 [00:15<00:08, 1874.36it/s]
# Extracting files (1/8:  52%|█████▏    | 15885/30700 [00:15<00:07, 1917.89it/s]
# Extracting files (1/8:  52%|█████▏    | 16091/30700 [00:15<00:08, 1782.77it/s]
# Extracting files (1/8:  53%|█████▎    | 16293/30700 [00:15<00:07, 1845.20it/s]
# Extracting files (1/8:  54%|█████▎    | 16487/30700 [00:15<00:07, 1787.32it/s]
# Extracting files (1/8:  54%|█████▍    | 16673/30700 [00:15<00:08, 1716.67it/s]
# Extracting files (1/8:  55%|█████▍    | 16857/30700 [00:16<00:07, 1749.74it/s]
# Extracting files (1/8:  56%|█████▌    | 17053/30700 [00:16<00:07, 1806.69it/s]
# Extracting files (1/8:  56%|█████▌    | 17237/30700 [00:16<00:07, 1799.17it/s]
# Extracting files (1/8:  57%|█████▋    | 17419/30700 [00:16<00:09, 1330.28it/s]
# Extracting files (1/8:  57%|█████▋    | 17583/30700 [00:16<00:09, 1400.09it/s]
# Extracting files (1/8:  58%|█████▊    | 17739/30700 [00:16<00:16, 769.77it/s]
# Extracting files (1/8:  58%|█████▊    | 17858/30700 [00:17<00:15, 834.76it/s]
# Extracting files (1/8:  59%|█████▊    | 17977/30700 [00:17<00:16, 753.91it/s]
# Extracting files (1/8:  59%|█████▉    | 18101/30700 [00:17<00:14, 841.50it/s]
# Extracting files (1/8:  60%|█████▉    | 18267/30700 [00:17<00:12, 1008.49it/s]
# Extracting files (1/8:  60%|█████▉    | 18392/30700 [00:17<00:15, 770.55it/s]
# Extracting files (1/8:  60%|██████    | 18494/30700 [00:17<00:16, 726.26it/s]
# Extracting files (1/8:  61%|██████    | 18584/30700 [00:18<00:19, 611.79it/s]
# Extracting files (1/8:  61%|██████    | 18686/30700 [00:18<00:18, 655.24it/s]
# Extracting files (1/8:  61%|██████    | 18763/30700 [00:18<00:19, 619.85it/s]
# Extracting files (1/8:  61%|██████▏   | 18839/30700 [00:18<00:18, 648.78it/s]
# Extracting files (1/8:  62%|██████▏   | 18911/30700 [00:18<00:22, 513.44it/s]
# Extracting files (1/8:  62%|██████▏   | 19019/30700 [00:18<00:18, 626.74it/s]
# Extracting files (1/8:  62%|██████▏   | 19093/30700 [00:19<00:20, 553.41it/s]
# Extracting files (1/8:  62%|██████▏   | 19157/30700 [00:19<00:22, 519.91it/s]
# Extracting files (1/8:  63%|██████▎   | 19215/30700 [00:19<00:23, 488.48it/s]
# Extracting files (1/8:  63%|██████▎   | 19274/30700 [00:19<00:22, 509.77it/s]
# Extracting files (1/8:  63%|██████▎   | 19344/30700 [00:19<00:20, 554.41it/s]
# Extracting files (1/8:  63%|██████▎   | 19421/30700 [00:19<00:18, 605.87it/s]
# Extracting files (1/8:  64%|██████▎   | 19515/30700 [00:19<00:16, 693.85it/s]
# Extracting files (1/8:  64%|██████▍   | 19609/30700 [00:19<00:14, 759.87it/s]
# Extracting files (1/8:  64%|██████▍   | 19717/30700 [00:19<00:12, 848.32it/s]
# Extracting files (1/8:  65%|██████▍   | 19805/30700 [00:20<00:13, 778.54it/s]
# Extracting files (1/8:  65%|██████▍   | 19919/30700 [00:20<00:12, 876.38it/s]
# Extracting files (1/8:  65%|██████▌   | 20010/30700 [00:20<00:16, 646.84it/s]
# Extracting files (1/8:  66%|██████▌   | 20126/30700 [00:20<00:13, 761.80it/s]
# Extracting files (1/8:  66%|██████▌   | 20231/30700 [00:20<00:12, 831.68it/s]
# Extracting files (1/8:  66%|██████▋   | 20340/30700 [00:20<00:11, 898.08it/s]
# Extracting files (1/8:  67%|██████▋   | 20470/30700 [00:20<00:10, 1004.54it/s]
# Extracting files (1/8:  67%|██████▋   | 20602/30700 [00:20<00:09, 1089.55it/s]
# Extracting files (1/8:  67%|██████▋   | 20717/30700 [00:21<00:16, 587.41it/s]
# Extracting files (1/8:  79%|███████▉  | 24198/30700 [00:26<00:22, 286.20it/s]
# Extracting files (1/8:  79%|███████▉  | 24344/30700 [00:26<00:15, 422.84it/s]
# Extracting files (1/8:  80%|███████▉  | 24464/30700 [00:26<00:11, 533.60it/s]
# Extracting files (1/8:  80%|████████  | 24576/30700 [00:26<00:09, 632.13it/s]
# Extracting files (1/8:  80%|████████  | 24695/30700 [00:26<00:08, 740.41it/s]
# Extracting files (1/8:  81%|████████  | 24802/30700 [00:26<00:07, 803.76it/s]
# Extracting files (1/8:  81%|████████  | 24907/30700 [00:26<00:07, 759.97it/s]
# Extracting files (1/8:  82%|████████▏ | 25048/30700 [00:27<00:06, 908.24it/s]
# Extracting files (1/8:  82%|████████▏ | 25191/30700 [00:27<00:05, 1035.99it/s]
# Extracting files (1/8:  82%|████████▏ | 25310/30700 [00:27<00:05, 1068.41it/s]
# Extracting files (1/8:  83%|████████▎ | 25526/30700 [00:27<00:03, 1361.84it/s]
# Extracting files (1/8:  84%|████████▎ | 25708/30700 [00:27<00:03, 1488.94it/s]
# Extracting files (1/8:  84%|████████▍ | 25929/30700 [00:27<00:02, 1692.09it/s]
# Extracting files (1/8:  85%|████████▌ | 26142/30700 [00:27<00:02, 1817.21it/s]
# Extracting files (1/8:  86%|████████▌ | 26330/30700 [00:28<00:07, 622.95it/s]
# Extracting files (1/8:  86%|████████▋ | 26512/30700 [00:28<00:05, 771.26it/s]
# Extracting files (1/8:  87%|████████▋ | 26664/30700 [00:28<00:05, 777.14it/s]
# Extracting files (1/8:  87%|████████▋ | 26827/30700 [00:28<00:04, 909.53it/s]
# Extracting files (1/8:  88%|████████▊ | 26966/30700 [00:28<00:03, 975.27it/s]
# Extracting files (1/8:  88%|████████▊ | 27101/30700 [00:29<00:03, 1041.58it/s]
# Extracting files (1/8:  89%|████████▊ | 27236/30700 [00:29<00:03, 1096.86it/s]
# Extracting files (1/8:  89%|████████▉ | 27368/30700 [00:29<00:03, 1097.03it/s]
# Extracting files (1/8:  90%|████████▉ | 27493/30700 [00:29<00:06, 507.72it/s]
# Extracting files (1/8:  90%|████████▉ | 27604/30700 [00:29<00:05, 589.74it/s]
# Extracting files (1/8:  90%|█████████ | 27703/30700 [00:30<00:04, 640.72it/s]
# Extracting files (1/8:  91%|█████████ | 27816/30700 [00:30<00:03, 730.95it/s]
# Extracting files (1/8:  91%|█████████ | 27917/30700 [00:30<00:03, 708.97it/s]
# Extracting files (1/8:  91%|█████████▏| 28028/30700 [00:30<00:03, 793.30it/s]
# Extracting files (1/8:  92%|█████████▏| 28220/30700 [00:30<00:02, 1054.31it/s]
# Extracting files (1/8:  92%|█████████▏| 28345/30700 [00:30<00:02, 1010.00it/s]
# Extracting files (1/8:  93%|█████████▎| 28516/30700 [00:30<00:01, 1181.87it/s]
# Extracting files (1/8:  93%|█████████▎| 28692/30700 [00:30<00:01, 1331.98it/s]
# Extracting files (1/8:  94%|█████████▍| 28837/30700 [00:31<00:01, 1216.54it/s]
# Extracting files (1/8:  94%|█████████▍| 28983/30700 [00:31<00:01, 1277.70it/s]
# Extracting files (1/8:  95%|█████████▍| 29119/30700 [00:31<00:01, 815.34it/s]
# Extracting files (1/8:  95%|█████████▌| 29258/30700 [00:31<00:01, 923.31it/s]
# Extracting files (1/8:  96%|█████████▌| 29375/30700 [00:31<00:02, 660.66it/s]
# Extracting files (1/8:  96%|█████████▌| 29493/30700 [00:31<00:01, 750.20it/s]
# Extracting files (1/8:  97%|█████████▋| 29702/30700 [00:32<00:00, 1015.14it/s]
# Extracting files (1/8:  97%|█████████▋| 29873/30700 [00:32<00:00, 1167.62it/s]
# Extracting files (1/8:  98%|█████████▊| 30018/30700 [00:32<00:00, 1221.18it/s]
# Extracting files (1/8:  98%|█████████▊| 30161/30700 [00:32<00:00, 1108.01it/s]
# Extracting files (1/8:  99%|█████████▉| 30325/30700 [00:32<00:00, 1234.96it/s]
# Extracting files (1/8:  99%|█████████▉| 30484/30700 [00:32<00:00, 1324.99it/s]
# Extracting files (1/8: 100%|██████████| 30700/30700 [00:32<00:00, 935.77it/s]
#
# Extracting files (1/8:   0%|          | 0/30700 [00:00<?, ?it/s]
# Extracting files (1/8:   0%|          | 1/30700 [00:00<5:25:30,  1.57it/s]
# Extracting files (1/8:   1%|          | 340/30700 [00:00<00:48, 622.82it/s]
# Extracting files (1/8:   3%|▎         | 807/30700 [00:00<00:20, 1462.60it/s]
# Extracting files (1/8:   4%|▎         | 1129/30700 [00:00<00:16, 1765.27it/s]
# Extracting files (1/8:   5%|▍         | 1426/30700 [00:01<00:27, 1082.10it/s]
# Extracting files (1/8:   7%|▋         | 2159/30700 [00:01<00:14, 2026.62it/s]
# Extracting files (1/8:  10%|▉         | 2926/30700 [00:01<00:09, 3028.45it/s]
# Extracting files (1/8:  12%|█▏        | 3683/30700 [00:01<00:06, 3947.24it/s]
# Extracting files (1/8:  14%|█▍        | 4420/30700 [00:01<00:05, 4713.72it/s]
# Extracting files (1/8:  17%|█▋        | 5197/30700 [00:01<00:04, 5455.06it/s]
# Extracting files (1/8:  19%|█▉        | 5933/30700 [00:02<00:04, 5943.84it/s]
# Extracting files (1/8:  22%|██▏       | 6630/30700 [00:02<00:03, 6200.99it/s]
# Extracting files (1/8:  24%|██▍       | 7325/30700 [00:02<00:03, 6087.26it/s]
# Extracting files (1/8:  26%|██▌       | 7986/30700 [00:02<00:03, 5882.76it/s]
# Extracting files (1/8:  28%|██▊       | 8612/30700 [00:02<00:03, 5679.24it/s]
# Extracting files (1/8:  30%|██▉       | 9207/30700 [00:02<00:03, 5577.46it/s]
# Extracting files (1/8:  32%|███▏      | 9917/30700 [00:02<00:03, 5987.33it/s]
# Extracting files (1/8:  35%|███▍      | 10639/30700 [00:02<00:03, 6329.69it/s]
# Extracting files (1/8:  37%|███▋      | 11420/30700 [00:02<00:02, 6750.24it/s]
# Extracting files (1/8:  40%|███▉      | 12178/30700 [00:03<00:02, 6988.78it/s]
# Extracting files (1/8:  42%|████▏     | 12887/30700 [00:03<00:02, 6687.62it/s]
# Extracting files (1/8:  44%|████▍     | 13565/30700 [00:03<00:05, 3340.94it/s]
# Extracting files (1/8:  47%|████▋     | 14338/30700 [00:03<00:04, 4079.35it/s]
# Extracting files (1/8:  49%|████▉     | 15116/30700 [00:03<00:03, 4796.21it/s]
# Extracting files (1/8:  52%|█████▏    | 15898/30700 [00:03<00:02, 5451.62it/s]
# Extracting files (1/8:  54%|█████▍    | 16594/30700 [00:03<00:02, 5806.91it/s]
# Extracting files (1/8:  57%|█████▋    | 17355/30700 [00:04<00:02, 6260.75it/s]
# Extracting files (1/8:  59%|█████▉    | 18068/30700 [00:04<00:01, 6387.64it/s]
# Extracting files (1/8:  61%|██████▏   | 18846/30700 [00:04<00:01, 6764.37it/s]
# Extracting files (1/8:  64%|██████▎   | 19570/30700 [00:04<00:01, 6611.20it/s]
# Extracting files (1/8:  66%|██████▌   | 20265/30700 [00:04<00:01, 6335.82it/s]
# Extracting files (1/8:  68%|██████▊   | 21028/30700 [00:04<00:01, 6687.15it/s]
# Extracting files (1/8:  71%|███████   | 21804/30700 [00:04<00:01, 6987.18it/s]
# Extracting files (1/8:  74%|███████▎  | 22602/30700 [00:04<00:01, 7269.96it/s]
# Extracting files (1/8:  76%|███████▌  | 23378/30700 [00:04<00:00, 7410.35it/s]
# Extracting files (1/8:  79%|███████▊  | 24129/30700 [00:05<00:00, 7305.58it/s]
# Extracting files (1/8:  81%|████████  | 24867/30700 [00:05<00:00, 7272.96it/s]
# Extracting files (1/8:  83%|████████▎ | 25600/30700 [00:05<00:00, 7133.14it/s]
# Extracting files (1/8:  86%|████████▌ | 26318/30700 [00:05<00:00, 6708.10it/s]
# Extracting files (1/8:  88%|████████▊ | 27002/30700 [00:05<00:00, 6743.25it/s]
# Extracting files (1/8:  90%|█████████ | 27721/30700 [00:05<00:00, 6869.37it/s]
# Extracting files (1/8:  93%|█████████▎| 28413/30700 [00:05<00:00, 6259.02it/s]
# Extracting files (1/8:  95%|█████████▍| 29052/30700 [00:05<00:00, 5581.71it/s]
# Extracting files (1/8:  97%|█████████▋| 29630/30700 [00:05<00:00, 5537.32it/s]
# Extracting files (1/8: 100%|██████████| 30700/30700 [00:06<00:00, 5034.11it/s]
#  50%|█████     | 2/4 [01:29<01:28, 44.31s/it]
# Extracting files (2/8:   0%|          | 0/13743 [00:00<?, ?it/s]
# Extracting files (2/8:   0%|          | 1/13743 [00:00<2:57:40,  1.29it/s]
# Extracting files (2/8:   1%|          | 99/13743 [00:01<02:45, 82.23it/s]
# Extracting files (2/8:   2%|▏         | 207/13743 [00:01<01:11, 188.15it/s]
# Extracting files (2/8:   2%|▏         | 307/13743 [00:01<00:45, 294.91it/s]
# Extracting files (2/8:   3%|▎         | 448/13743 [00:01<00:28, 471.15it/s]
# Extracting files (2/8:   4%|▍         | 562/13743 [00:01<00:22, 593.95it/s]
# Extracting files (2/8:   5%|▍         | 682/13743 [00:01<00:18, 713.63it/s]
# Extracting files (2/8:   6%|▌         | 789/13743 [00:02<00:20, 625.75it/s]
# Extracting files (2/8:   7%|▋         | 929/13743 [00:02<00:16, 783.53it/s]
# Extracting files (3/8:   2%|▏         | 354/14960 [00:01<00:32, 449.19it/s]
# Extracting files (3/8:   5%|▍         | 725/14960 [00:01<00:14, 949.90it/s]
# Extracting files (3/8:   7%|▋         | 1064/14960 [00:01<00:10, 1385.67it/s]
# Extracting files (3/8:   9%|▉         | 1410/14960 [00:01<00:07, 1808.40it/s]
# Extracting files (3/8:  12%|█▏        | 1729/14960 [00:01<00:12, 1032.60it/s]
# Extracting files (3/8:  17%|█▋        | 2513/14960 [00:02<00:06, 1956.38it/s]
# Extracting files (3/8:  22%|██▏       | 3261/14960 [00:02<00:04, 2853.13it/s]
# Extracting files (3/8:  27%|██▋       | 4036/14960 [00:02<00:02, 3774.56it/s]
# Extracting files (3/8:  32%|███▏      | 4825/14960 [00:02<00:02, 4646.62it/s]
# Extracting files (3/8:  37%|███▋      | 5575/14960 [00:02<00:01, 5308.25it/s]
# Extracting files (3/8:  42%|████▏     | 6322/14960 [00:02<00:01, 5846.70it/s]
# Extracting files (3/8:  47%|████▋     | 7031/14960 [00:02<00:01, 6171.06it/s]
# Extracting files (3/8:  52%|█████▏    | 7781/14960 [00:02<00:01, 6532.70it/s]
# Extracting files (3/8:  57%|█████▋    | 8500/14960 [00:02<00:00, 6687.49it/s]
# Extracting files (3/8:  62%|██████▏   | 9216/14960 [00:02<00:00, 6361.63it/s]
# Extracting files (3/8:  66%|██████▌   | 9898/14960 [00:03<00:00, 6486.88it/s]
# Extracting files (3/8:  71%|███████▏  | 10695/14960 [00:03<00:00, 6903.93it/s]
# Extracting files (3/8:  76%|███████▋  | 11407/14960 [00:03<00:00, 5884.31it/s]
# Extracting files (3/8:  80%|████████  | 12036/14960 [00:03<00:00, 5004.06it/s]
# Extracting files (3/8:  84%|████████▍ | 12583/14960 [00:03<00:00, 4873.36it/s]
# Extracting files (3/8:  88%|████████▊ | 13213/14960 [00:03<00:00, 5218.59it/s]
# Extracting files (3/8:  93%|█████████▎| 13925/14960 [00:03<00:00, 5706.93it/s]
# Extracting files (3/8: 100%|██████████| 14960/14960 [00:03<00:00, 3748.86it/s]
# 100%|██████████| 4/4 [02:10<00:00, 32.75s/it]

# %%
# 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/images'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/images contains 90477 files.

# %%
# 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/json_day_night'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/json_day_night contains 90477 files.

# %% [markdown]
# # 주간 / 야간 json 데이터 분리

# %%
import os
import json
import shutil

# !mkdir /content/train/Dataset/night_json
# !mkdir /content/train/Dataset/day_json

# 디렉토리 내의 모든 json 파일 목록을 가져오기
file_list = os.listdir('/content/train/Dataset/json_day_night')

for file_name in file_list:
  if file_name.endswith('.json'): # json 파일일 경우
    with open('/content/train/Dataset/json_day_night/' + file_name, 'r') as f:
      data = json.load(f)
      if data['images'][0]['day'] == 'night':
        shutil.copy('/content/train/Dataset/json_day_night/' + file_name, '/content/train/Dataset/night_json/'+file_name)
      elif data['images'][0]['day'] == 'day':
        shutil.copy('/content/train/Dataset/json_day_night/' + file_name, '/content/train/Dataset/day_json/'+file_name)

# %%
# 야간 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/night_json'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/night_json contains 42222 files.

# %%
# 주간 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/day_json'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/day_json contains 48255 files.

# %%
# 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/labels'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/labels contains 0 files.

# %% [markdown]
# # 야생동물 JSON 데이터 txt 파일로 수정

# %%
# json 형태의 annotation 데이터를 YOLOv5 학습 형태에 맞게 txt 로 변환한다.
# 변환된 데이터는 ./Dataset/labels 에 저장됩니다.

classification = []
count = []

TOP = 0
LEFT = 1
BOTTOM = 2
RIGHT = 3

SQURE = 1

class Label:

	def __init__(self, fileName, imagePath):
		data = self.parse_json_data(fileName)
		self.set_data(data, fileName, imagePath)

	def parse_json_data(self, fileName):
		with open(fileName, encoding='utf-8-sig') as jsonFile:
			jsonData = json.load(jsonFile)
		return jsonData

	def set_data(self, data, fileName, imagePath):
		self.fileName = '.'.join(os.path.basename(fileName).split('.')[0:-1])
		self.width = int(data['images'][0]['width'])
		self.height = int(data['images'][0]['height'])
		self.annotations = data['annotations']

	def get_bbox_point(self, bbox):
		top = 10000
		left = 10000
		bottom = -1
		right = -1

		for i in bbox:
			if (i[0] < left): left = i[0]
			if (i[0] > right): right = i[0]
			if (i[1] < top): top = i[1]
			if (i[1] > bottom): bottom = i[1]

		return ((top, left, bottom, right))

	def get_segment_point(self, seg):
		top = 10000
		left = 10000
		bottom = -1
		right = -1

		for i in range(len(seg)):
			if (i % 2 == 0):
				if (seg[i] < left): left = seg[i]
				if (seg[i] > right): right = seg[i]
			else:
				if (seg[i] < top): top = seg[i]
				if (seg[i] > bottom): bottom = seg[i]

		return ((top, left, bottom, right))

	def get_shape_point(self, shape):
		try: #종혁 : 추가
			if (shape['bbox'] and len(shape['bbox']) != 0):
				return self.get_bbox_point(shape['bbox'])
			elif (shape['Segmentation'] and len(shape['Segmentation']) != 0):
				return self.get_segment_point(shape['Segmentation'][0])
			else:
				return (0, 0, 0, 0)
		except: #종혁 : 추가
			return (0, 0, 0, 0) #종혁 : 추가

	def point_to_txt(self, point):
		if (point[0]) not in classification:
			classification.append(point[0])
			count.append(0)
		idx = classification.index(point[0])
		count[idx] += 1

		if (SQURE):
			r = (self.width - self.height) / 2
			w_center = ((point[1][LEFT] + point[1][RIGHT]) / 2) / self.width
			h_center = (((point[1][TOP] + point[1][BOTTOM]) / 2) + r) / self.width
			w_len = (point[1][RIGHT] - point[1][LEFT]) / self.width
			h_len = (point[1][BOTTOM] - point[1][TOP]) / self.width
		else:
			w_center = ((point[1][LEFT] + point[1][RIGHT]) / 2) / self.width
			h_center = ((point[1][TOP] + point[1][BOTTOM]) / 2) / self.height
			w_len = (point[1][RIGHT] - point[1][LEFT]) / self.width
			h_len = (point[1][BOTTOM] - point[1][TOP]) / self.height
		return (idx, w_center, h_center, w_len, h_len)

	def convert_data(self):
		self.points = []
		self.txt = []
		for shape in self.annotations:
			self.points.append((shape['species'], self.get_shape_point(shape)))
		for point in self.points:
			self.txt.append(self.point_to_txt(point))

	def write_data(self, path):
		with open(path + self.fileName + ".txt", 'w') as f:
			for line in self.txt:
				f.write(' '.join(map(str, line)) + "\n")

def convert_data(file, targetPath, imagePath):
	target = Label(file, imagePath)
	target.convert_data()
	target.write_data(targetPath)

json_count = [0]
def convert(targetPath, src):
    # 원코드
    # from tqdm import tqdm
    # data_list = os.listdir(targetPath)
    # print(data_list) #추가
    # for line in data_list:
    #     print(os.path.join(targetPath, line)) # 추가
    #     if os.path.isdir(os.path.join(targetPath, line) + '/'):
    #         convert(os.path.join(targetPath, line), src)
    #         # 종혁 : 재귀적 함수? 와.. 이렇게 짜는 거구나.
    #         # 근데 그래서 속도가 느릴 거 같은데..
    #     elif '.json' in line:
    #         json_count[0] += 1
    #         print(json_count[0], "Data Convert:", line, end='\r')
    #         # shutil.copyfile(targetPath + "/" + line, src + "/json/" + line)
    #         # 비효율적인 코드 삭제 ==> 대신 OriginData 폴더와 json 폴더에 TL 파일들 넣어야 함
    #         convert_data(targetPath + "/" + line, src + "/labels/", src + "/images/")
    #     else:
    #        pass
    
    from tqdm import tqdm
    
    path = src + '/day_json'
    data_list = os.listdir(path)
    json_count = [0]
    
    for line in tqdm(data_list):
        json_count[0] += 1
        convert_data(path + '/' + line, src + '/labels/', src + '/images/')
        
    

image_count = [0]
def copy_image(targetPath, src):
	data_list = os.listdir(targetPath)
	for line in data_list:
		if os.path.isdir(os.path.join(targetPath, line)):
			copy_image(os.path.join(targetPath, line), src)
		elif '.jpg' in line:
			image_count[0] += 1
			print(image_count[0], "Image Copy:", line, end='\r')
			shutil.copyfile(targetPath + "/" + line, src + "/images/" + line)
		else:
			pass

def write_yaml(target):
	data = {}
	data["names"] = classification
	data["nc"] = len(classification)
	data["train"] = "../Dataset/train.txt"
	data["val"] = "../Dataset/valid.txt"
	data["test"] = "../Dataset/test.txt"
	with open(target, 'w', encoding='utf-8-sig') as f:
		yaml.dump(data, f, allow_unicode=True)

def run_convert(targetPath, src, copy):
	if not os.path.isdir(src + "/images"):
		os.makedirs(src + "/images/")
	if not os.path.isdir(src + "/labels"):
		os.makedirs(src + "/labels")
	if not os.path.isdir(src + "/json"):
		os.makedirs(src + "/json")
	# if copy:
	# 	copy_image(targetPath, src)
	# 비효율적인 코드 삭제 ==> 대신 image 폴더에 직접 이미지 넣어야 함
	convert(targetPath, src)
	write_yaml(os.path.join(src, "data.yaml"))
	for i in range(len(classification)):
		print(classification[i], "is counted:", count[i])



# 로컬 실행시
# import time
# start = time.time()
# run_convert("./OriginData", "./Dataset", False)
# end = time.time()
# print(f'{end - start:.5f} sec')


# 코랩 실행시
## 종혁 : 경로 재설정, 소요시간 기록
## run_convert(,,False) : False = 복사를 하지 않음
main_path = main_path
start = time.time()

run_convert("OriginData", main_path + "Dataset", False)
# 메인 코드 : 컨버팅

end = time.time()
print(f'{end - start:.5f} sec')
# Out:
# 100%|██████████| 48255/48255 [00:10<00:00, 4593.71it/s]
# 고라니 is counted: 18115
# 반달가슴곰 is counted: 16282
# 너구리 is counted: 8814
# 멧돼지 is counted: 17249
# 노루 is counted: 9
# 10.54261 sec

# %%
# 파일 개수 확인

import os

# Set folder path
source_folder = '/content/train/Dataset/labels'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')
# Out:
# The folder /content/train/Dataset/labels contains 48255 files.

# %% [markdown]
# # 야생동물 데이터 class id (숫자) 인덱스 값 바꾸기

# %%
# 불필요한 노루 객체의 txt 데이터 삭제하기

import os

# 특정 폴더 내의 모든 txt 파일 가져오기
folder_path = '/content/train/Dataset/labels'
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# 파일별로 <class-id> 확인하고, 4이면 삭제 수행
num_deleted_files = 0
for txt_file in txt_files:
    with open(os.path.join(folder_path, txt_file), 'r') as f:
        lines = f.readlines()
    class_ids = [int(line.strip().split()[0]) for line in lines]
    if 4 in class_ids :
        os.remove(os.path.join(folder_path, txt_file))
        num_deleted_files += 1

print(f"{num_deleted_files}개의 파일이 삭제되었습니다.")
# Out:
# 9개의 파일이 삭제되었습니다.

# %%
import os

# number conversion function
def convert_class_id(class_id):
    if class_id == 0 :
        return 0
    elif class_id == 1 :
        return 2    
    elif class_id == 2 :
        return 3    
    elif class_id == 3 :
        return 1    
    # else:
    #     return 5


# Get all txt files in a specific folder
folder_path = '/content/train/Dataset/labels'
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Counter for files that caused errors
num_error_files = 0

# Counter for files that were successfully modified
num_success_files = 0

# Perform <class-id> conversion per file
for txt_file in txt_files:
    with open(os.path.join(folder_path, txt_file), 'r') as f:
        lines = f.readlines()
    new_lines = []
    try:
        for line in lines:
            class_id, x, y, width, height = map(float, line.strip().split(' '))
            new_class_id = convert_class_id(int(class_id))
            new_lines.append(f'{new_class_id} {x} {y} {width} {height}\n')
        with open(os.path.join(folder_path, txt_file), 'w') as f:
            f.writelines(new_lines)
            num_success_files += 1
    except ValueError:
        # Increment counter for files that caused errors
        num_error_files += 1
        continue

print(f'Total number of files that caused errors: {num_error_files}')
print(f'Total number of files successfully modified: {num_success_files}')
# Out:
# Total number of files that caused errors: 0
# Total number of files successfully modified: 48246

# %%
# 특정 클래스 id 를 가진 텍스트 파일 조회하기

folder_path = '/content/train/Dataset/labels'  # 조회할 폴더 경로

num_files = 0  # 조회된 파일 개수
found_files = []  # 클래스 아이디가 발견된 파일 목록

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):  # 확장자가 .txt인 파일들만 조회
        with open(os.path.join(folder_path, file_name), 'r') as f:
            lines = f.readlines()
            found_class_id = False
            for line in lines:
                if len(line.split()) >= 1:
                    class_id = int(line.split()[0])
                    if class_id == 5:  # 클래스 아이디가 4인 파일만 개수 증가
                        num_files += 1
                        found_class_id = True
                        break  # 이 파일은 더 이상 조회할 필요 없음
            if found_class_id:
                found_files.append(file_name)
            # else:
            #     print(f'Warning: No object with class-id 1 found in file {file_name}')

print(f'Total number of files with <class-id>4</class-id>: {num_files}')
print(f'Files with <class-id>4</class-id>: {found_files}')
# Out:
# Total number of files with <class-id>4</class-id>: 0
# Files with <class-id>4</class-id>: []

# %%
# 특정 클래스 id 를 가진 텍스트 파일 조회하기

folder_path = '/content/train/Dataset/labels'  # 조회할 폴더 경로

num_files = 0  # 조회된 파일 개수
found_files = []  # 클래스 아이디가 발견된 파일 목록

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):  # 확장자가 .txt인 파일들만 조회
        with open(os.path.join(folder_path, file_name), 'r') as f:
            lines = f.readlines()
            found_class_id = False
            for line in lines:
                if len(line.split()) >= 1:
                    class_id = int(line.split()[0])
                    if class_id == 0:  # 클래스 아이디가 4인 파일만 개수 증가
                        num_files += 1
                        found_class_id = True
                        break  # 이 파일은 더 이상 조회할 필요 없음
            if found_class_id:
                found_files.append(file_name)
            # else:
            #     print(f'Warning: No object with class-id 1 found in file {file_name}')

print(f'Total number of files with <class-id>4</class-id>: {num_files}')
print(f'Files with <class-id>4</class-id>: {found_files}')
# Out:
# Total number of files with <class-id>4</class-id>: 8814
# Files with <class-id>4</class-id>: ['A03_H20_C015_C_211124_1001_30S_000018.014.txt', 'A03_H29_C007_C_211118_1032_30S_000019.013.txt', 'A03_H20_C013_C_211122_1220_30S_000012.005.txt', 'A03_H20_C012_C_211123_1004_29S_000001.024.txt', 'A03_H20_C014_C_211112_4024_20S_000011.905.txt', 'A03_H20_C012_C_211123_1021_29S_000003.018.txt', 'A03_H20_C015_C_211124_1007_30S_000002.026.txt', 'A03_H20_C014_C_211112_4024_20S_000002.972.txt', 'A03_H20_C012_C_211123_1012_29S_000006.026.txt', 'A03_H20_C015_C_211124_1003_30S_000019.003.txt', 'A03_H20_C014_C_211112_4025_20S_000006.672.txt', 'A03_H20_C015_C_211124_1001_30S_000010.017.txt', 'A03_H20_C015_C_211124_1003_30S_000029.008.txt', 'A03_H20_C012_C_211123_1002_29S_000002.021.txt', 'A03_H20_C013_C_211122_1226_30S_000029.016.txt', 'A03_H20_C013_C_211122_1212_30S_000009.015.txt', 'A03_H20_C012_C_211123_1007_10S_000002.021.txt', 'A03_H20_C012_C_211123_1015_13S_000011.017.txt', 'A03_H20_C012_C_211123_1019_29S_000000.019.txt', 'A03_H29_C007_C_211118_1033_30S_000003.022.txt', 'A03_H20_C012_C_211123_1013_29S_000014.019.txt', 'A03_H20_C014_C_211112_4025_20S_000006.205.txt', 'A03_H29_C007_C_211118_1165_30S_000001.015.txt', 'A03_H20_C015_C_211124_1002_30S_000009.017.txt', 'A03_H29_C007_C_211118_1148_30S_000001.015.txt', 'A03_H20_C014_C_211112_4026_20S_000004.439.txt', 'A03_H20_C012_C_211123_1016_10S_000005.008.txt', 'A03_H20_C015_C_211124_1005_18S_000006.006.txt', 'A03_H20_C012_C_211123_1021_29S_000000.022.txt', 'A03_H20_C012_C_211123_1004_29S_000014.010.txt', 'A03_H20_C012_C_211123_1021_29S_000019.004.txt', 'A03_H29_C007_C_211118_1028_30S_000021.000.txt', 'A03_H20_C012_C_211123_1004_29S_000019.027.txt', 'A03_H20_C012_C_211123_1021_29S_000007.004.txt', 'A03_H20_C012
# Total 0 files were copied to class 10 folder.
# --------------------------------------------------
# Total 0 files were copied to class 11 folder.
# --------------------------------------------------
# Total 0 files were copied to class 12 folder.
# --------------------------------------------------
# Total 0 files were copied to class 13 folder.
# --------------------------------------------------
# Total 0 files were copied to class 14 folder.
# --------------------------------------------------
# Total 0 files were copied to class 15 folder.
# --------------------------------------------------
# Total 0 files were copied to class 16 folder.
# --------------------------------------------------
# Total 0 files were copied to class 17 folder.
# --------------------------------------------------
# Total 0 files were copied to class 18 folder.
# --------------------------------------------------
# Total 0 files were copied to class 19 folder.
# --------------------------------------------------
# Total 0 files were copied to class 20 folder.
# --------------------------------------------------
# Total 0 files were copied to class 21 folder.
# --------------------------------------------------
# Total 0 files were copied to class 22 folder.
# --------------------------------------------------
# Total 0 files were copied to class 23 folder.
# --------------------------------------------------
# Total 0 files were copied to class 24 folder.
# --------------------------------------------------
# Total 0 files were copied to class 25 folder.
# --------------------------------------------------
# Total 0 files were copied to class 26 folder.
# --------------------------------------------------
# Total 0 files were copied to class 27 folder.
# --------------------------------------------------
# Total 0 files were copied to class 28 folder.
# --------------------------------------------------
# Total 0 files were copied to class 29 folder.
# --------------------------------------------------
# Total 0 files were copied to class 30 folder.
# --------------------------------------------------
# Total 0 files were copied to class 31 folder.
# --------------------------------------------------
# Total 0 files were copied to class 32 folder.
# --------------------------------------------------
# Total 0 files were copied to class 33 folder.
# --------------------------------------------------
# Total 0 files were copied to class 34 folder.
# --------------------------------------------------
# Total 0 files were copied to class 35 folder.
# --------------------------------------------------
# Total 0 files were copied to class 36 folder.
# --------------------------------------------------
# Total 0 files were copied to class 37 folder.
# --------------------------------------------------
# Total 0 files were copied to class 38 folder.
# --------------------------------------------------
# Total 0 files were copied to class 39 folder.
# --------------------------------------------------
# Total 0 files were copied to class 40 folder.
# --------------------------------------------------
# Total 0 files were copied to class 41 folder.
# --------------------------------------------------
# Total 0 files were copied to class 42 folder.
# --------------------------------------------------
# Total 0 files were copied to class 43 folder.
# --------------------------------------------------
# Total 0 files were copied to class 44 folder.
# --------------------------------------------------
# Total 0 files were copied to class 45 folder.
# --------------------------------------------------
# Total 0 files were copied to class 46 folder.
# --------------------------------------------------
# Total 0 files were copied to class 47 folder.
# --------------------------------------------------
# Total 0 files were copied to class 48 folder.
# --------------------------------------------------
# Total 0 files were copied to class 49 folder.
# --------------------------------------------------
# Total 0 files were copied to class 50 folder.
# --------------------------------------------------
# Total 0 files were copied to class 51 folder.
# --------------------------------------------------
# Total 0 files were copied to class 52 folder.
# --------------------------------------------------
# Total 0 files were copied to class 53 folder.
# --------------------------------------------------
# Total 0 files were copied to class 54 folder.
# --------------------------------------------------
# Total 0 files were copied to class 55 folder.
# --------------------------------------------------
# Total 0 files were copied to class 56 folder.
# --------------------------------------------------
# Total 0 files were copied to class 57 folder.
# --------------------------------------------------
# Total 0 files were copied to class 58 folder.
# --------------------------------------------------
# Total 0 files were copied to class 59 folder.
# --------------------------------------------------
# Total 0 files were copied to class 60 folder.
# --------------------------------------------------
# Total 0 files were copied to class 61 folder.
# --------------------------------------------------
# Total 0 files were copied to class 62 folder.
# --------------------------------------------------
# Total 0 files were copied to class 63 folder.
# --------------------------------------------------
# Total 0 files were copied to class 64 folder.
# --------------------------------------------------
# Total 0 files were copied to class 65 folder.
# --------------------------------------------------
# Total 0 files were copied to class 66 folder.
# --------------------------------------------------
# Total 0 files were copied to class 67 folder.
# --------------------------------------------------
# Total 0 files were copied to class 68 folder.
# --------------------------------------------------
# Total 0 files were copied to class 69 folder.
# --------------------------------------------------
# Total 0 files were copied to class 70 folder.
# --------------------------------------------------
# Total 0 files were copied to class 71 folder.
# --------------------------------------------------
# Total 0 files were copied to class 72 folder.
# --------------------------------------------------
# Total 0 files were copied to class 73 folder.
# --------------------------------------------------
# Total 0 files were copied to class 74 folder.
# --------------------------------------------------
# Total 0 files were copied to class 75 folder.
# --------------------------------------------------
# Total 0 files were copied to class 76 folder.
# --------------------------------------------------
# Total 0 files were copied to class 77 folder.
# --------------------------------------------------
# Total 0 files were copied to class 78 folder.
# --------------------------------------------------
# Total 0 files were copied to class 79 folder.
# --------------------------------------------------

# %%
import os

# specify the path to the folder
path = "/content/train/Dataset/labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")
# Out:
# /content/train/Dataset/labels: 48246

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/first_class_labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")
# Out:
# /content/train/DistDataset/first_class_labels: 0
# /content/train/DistDataset/first_class_labels/70: 0
# /content/train/DistDataset/first_class_labels/78: 0
# /content/train/DistDataset/first_class_labels/20: 0
# /content/train/DistDataset/first_class_labels/10: 0
# /content/train/DistDataset/first_class_labels/54: 0
# /content/train/DistDataset/first_class_labels/13: 0
# /content/train/DistDataset/first_class_labels/56: 0
# /content/train/DistDataset/first_class_labels/49: 0
# /content/train/DistDataset/first_class_labels/57: 0
# /content/train/DistDataset/first_class_labels/62: 0
# /content/train/DistDataset/first_class_labels/53: 0
# /content/train/DistDataset/first_class_labels/64: 0
# /content/train/DistDataset/first_class_labels/24: 0
# /content/train/DistDataset/first_class_labels/48: 0
# /content/train/DistDataset/first_class_labels/25: 0
# /content/train/DistDataset/first_class_labels/66: 0
# /content/train/DistDataset/first_class_labels/23: 0
# /content/train/DistDataset/first_class_labels/58: 0
# /content/train/DistDataset/first_class_labels/59: 0
# /content/train/DistDataset/first_class_labels/12: 0
# /content/train/DistDataset/first_class_labels/61: 0
# /content/train/DistDataset/first_class_labels/4: 0
# /content/train/DistDataset/first_class_labels/11: 0
# /content/train/DistDataset/first_class_labels/6: 0
# /content/train/DistDataset/first_class_labels/42: 0
# /content/train/DistDataset/first_class_labels/76: 0
# /content/train/DistDataset/first_class_labels/79: 0
# /content/train/DistDataset/first_class_labels/74: 0
# /content/train/DistDataset/first_class_labels/27: 0
# /content/train/DistDataset/first_class_labels/9: 0
# /content/train/DistDataset/first_class_labels/14: 0
# /content/train/DistDataset/first_class_labels/29: 0
# /content/train/DistDataset/first_class_labels/21: 0
# /content/train/DistDataset/first_class_labels/33: 0
# /content/train/DistDataset/first_class_labels/55: 0
# /content/train/DistDataset/first_class_labels/77: 0
# /content/train/DistDataset/first_class_labels/44: 0
# /content/train/DistDataset/first_class_labels/31: 0
# /content/train/DistDataset/first_class_labels/40: 0
# /content/train/DistDataset/first_class_labels/43: 0
# /content/train/DistDataset/first_class_labels/72: 0
# /content/train/DistDataset/first_class_labels/46: 0
# /content/train/DistDataset/first_class_labels/37: 0
# /content/train/DistDataset/first_class_labels/69: 0
# /content/train/DistDataset/first_class_labels/52: 0
# /content/train/DistDataset/first_class_labels/18: 0
# /content/train/DistDataset/first_class_labels/36: 0
# /content/train/DistDataset/first_class_labels/60: 0
# /content/train/DistDataset/first_class_labels/2: 8424
# /content/train/DistDataset/first_class_labels/16: 0
# /content/train/DistDataset/first_class_labels/22: 0
# /content/train/DistDataset/first_class_labels/34: 0
# /content/train/DistDataset/first_class_labels/71: 0
# /content/train/DistDataset/first_class_labels/28: 0
# /content/train/DistDataset/first_class_labels/7: 0
# /content/train/DistDataset/first_class_labels/41: 0
# /content/train/DistDataset/first_class_labels/30: 0
# /content/train/DistDataset/first_class_labels/45: 0
# /content/train/DistDataset/first_class_labels/8: 0
# /content/train/DistDataset/first_class_labels/3: 8814
# /content/train/DistDataset/first_class_labels/65: 0
# /content/train/DistDataset/first_class_labels/75: 0
# /content/train/DistDataset/first_class_labels/35: 0
# /content/train/DistDataset/first_class_labels/17: 0
# /content/train/DistDataset/first_class_labels/50: 0
# /content/train/DistDataset/first_class_labels/5: 0
# /content/train/DistDataset/first_class_labels/39: 0
# /content/train/DistDataset/first_class_labels/1: 14050
# /content/train/DistDataset/first_class_labels/67: 0
# /content/train/DistDataset/first_class_labels/0: 16958
# /content/train/DistDataset/first_class_labels/19: 0
# /content/train/DistDataset/first_class_labels/73: 0
# /content/train/DistDataset/first_class_labels/38: 0
# /content/train/DistDataset/first_class_labels/68: 0
# /content/train/DistDataset/first_class_labels/32: 0
# /content/train/DistDataset/first_class_labels/26: 0
# /content/train/DistDataset/first_class_labels/47: 0
# /content/train/DistDataset/first_class_labels/63: 0
# /content/train/DistDataset/first_class_labels/51: 0
# /content/train/DistDataset/first_class_labels/15: 0

# %% [markdown]
# # coco dataset 세팅하기

# %%
# 압축 파일 경로를 설정해주세요.
# 리스트 형태이며, 여러 파일도 가능합니다.

zip_file_path_cocoimages = ['/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/cocoData/cocoimages.zip']


zip_file_path_cocolabels = ['/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/cocoData/cocolabels.zip']


# 본 Main 코드 폴더가 있는 폴더 경로를 지정해주세요.
# 압축이 풀린"이미지" 파일은 Main 코드가 있는 폴더 -> Dataset -> cocoimages 폴더로 들어갑니다.
# 압축이 풀린"json" 파일은 Main 코드가 있는 폴더 -> Dataset -> cocolabels 폴더로 들어갑니다.
# !mkdir /content/train/cocoDataset
# !mkdir /content/train/cocoDataset/cocoimages
# !mkdir /content/train/cocoDataset/cocolabels

main_path = '/content/train/'
google_drive_path = '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/코드/03. yolov7_train/'

# %%
# coco data 압축 해제

for i in tqdm(range(len(zip_file_path_cocoimages))):
  zip_file_cocoimages = zipfile.ZipFile(zip_file_path_cocoimages[i])
  file_list = zip_file_cocoimages.namelist()
  for file_name in tqdm(file_list, desc=f'Extracting files ({i}/{2*len(zip_file_path_cocoimages)}'):
    zip_file_cocoimages.extract(file_name, main_path + 'cocoDataset/cocoimages')

  zip_file_cocolabels = zipfile.ZipFile(zip_file_path_cocolabels[i])
  file_list = zip_file_cocolabels.namelist()
  for file_name in tqdm(file_list, desc = f'Extracting files ({i}/{2*len(zip_file_path_cocoimages)}'):
    zip_file_cocolabels.extract(file_name, main_path + 'cocoDataset/cocolabels')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting files (0/2:   0%|          | 0/116408 [00:00<?, ?it/s]
# Extracting files (0/2:   0%|          | 1/116408 [00:00<10:22:01,  3.12it/s]
# Extracting files (0/2:   0%|          | 68/116408 [00:00<09:52, 196.39it/s]
# Extracting files (0/2:   0%|          | 133/116408 [00:00<06:10, 313.93it/s]
# Extracting files (0/2:   0%|          | 271/116408 [00:00<03:19, 583.08it/s]
# Extracting files (0/2:   0%|          | 403/116408 [00:00<02:49, 682.85it/s]
# Extracting files (0/2:   0%|          | 519/116408 [00:00<02:24, 804.40it/s]
# Extracting files (0/2:   1%|          | 609/116408 [00:01<02:23, 808.23it/s]
# Extracting files (0/2:   1%|          | 697/116408 [00:01<02:36, 741.27it/s]
# Extracting files (0/2:   1%|          | 813/116408 [00:01<03:21, 574.53it/s]
# Extracting files (0/2:   1%|          | 1026/116408 [00:01<02:10, 884.23it/s]
# Extracting files (0/2:   1%|          | 1138/116408 [00:01<02:03, 935.38it/s]
# Extracting files (0/2:   1%|          | 1250/116408 [00:01<02:11, 874.80it/s]
# Extracting files (0/2:   1%|          | 1365/116408 [00:01<02:02, 938.76it/s]
# Extracting files (0/2:   1%|▏         | 1478/116408 [00:02<02:42, 708.92it/s]
# Extracting files (0/2:   1%|▏         | 1611/116408 [00:02<02:45, 693.81it/s]
# Extracting files (0/2:   2%|▏         | 1771/116408 [00:02<02:11, 869.70it/s]
# Extracting files (0/2:   2%|▏         | 1884/116408 [00:02<02:03, 926.05it/s]
# Extracting files (0/2:   2%|▏         | 2097/116408 [00:02<01:34, 1211.22it/s]
# Extracting files (0/2:   2%|▏         | 2236/116408 [00:02<01:59, 958.85it/s]
# Extracting files (0/2:   2%|▏         | 2438/116408 [00:03<01:35, 1187.44it/s]
# Extracting files (0/2:   2%|▏         | 2646/116408 [00:03<01:21, 1397.51it/s]
# Extracting files (0/2:   2%|▏         | 2863/116408 [00:03<01:11, 1590.47it/s]
# Extracting files (0/2:   3%|▎         | 3041/116408 [00:03<01:09, 1640.10it/s]
# Extracting files (0/2:   3%|▎         | 3219/116408 [00:03<01:07, 1673.30it/s]
# Extracting files (0/2:   3%|▎         | 3426/116408 [00:03<01:03, 1783.11it/s]
# Extracting files (0/2:   3%|▎         | 3638/116408 [00:03<01:00, 1876.72it/s]
# Extracting files (0/2:   3%|▎         | 3849/116408 [00:03<00:57, 1941.93it/s]
# Extracting files (0/2:   3%|▎         | 4054/116408 [00:03<00:56, 1972.54it/s]
# Extracting files (0/2:  99%|█████████▊| 114671/116408 [01:23<00:00, 1967.78it/s]
# Extracting files (0/2:  99%|█████████▊| 114869/116408 [01:23<00:00, 1963.23it/s]
# Extracting files (0/2:  99%|█████████▉| 115084/116408 [01:23<00:00, 2016.00it/s]
# Extracting files (0/2:  99%|█████████▉| 115296/116408 [01:23<00:00, 2045.69it/s]
# Extracting files (0/2:  99%|█████████▉| 115508/116408 [01:23<00:00, 2066.25it/s]
# Extracting files (0/2:  99%|█████████▉| 115731/116408 [01:23<00:00, 2112.61it/s]
# Extracting files (0/2: 100%|█████████▉| 115943/116408 [01:23<00:00, 2054.56it/s]
# Extracting files (0/2: 100%|█████████▉| 116158/116408 [01:23<00:00, 2081.69it/s]
# Extracting files (0/2: 100%|██████████| 116408/116408 [01:24<00:00, 1373.79it/s]
#
# Extracting files (0/2:   0%|          | 0/116408 [00:00<?, ?it/s]
# Extracting files (0/2:   0%|          | 1/116408 [00:00<17:29:12,  1.85it/s]
# Extracting files (0/2:   1%|          | 922/116408 [00:00<00:59, 1925.88it/s]
# Extracting files (0/2:   2%|▏         | 1892/116408 [00:00<00:30, 3712.29it/s]
# Extracting files (0/2:   2%|▏         | 2866/116408 [00:00<00:21, 5201.41it/s]
# Extracting files (0/2:   3%|▎         | 3839/116408 [00:00<00:17, 6381.44it/s]
# Extracting files (0/2:   4%|▍         | 4808/116408 [00:01<00:15, 7276.57it/s]
# Extracting files (0/2:   5%|▍         | 5772/116408 [00:01<00:13, 7935.74it/s]
# Extracting files (0/2:   6%|▌         | 6724/116408 [00:01<00:13, 8383.73it/s]
# Extracting files (0/2:   7%|▋         | 7685/116408 [00:01<00:12, 8736.71it/s]
# Extracting files (0/2:   7%|▋         | 8649/116408 [00:01<00:11, 9000.21it/s]
# Extracting files (0/2:   8%|▊         | 9616/116408 [00:01<00:11, 9196.50it/s]
# Extracting files (0/2:   9%|▉         | 10571/116408 [00:01<00:11, 9294.03it/s]
# Extracting files (0/2:  10%|▉         | 11529/116408 [00:01<00:11, 9377.04it/s]
# Extracting files (0/2:  11%|█         | 12493/116408 [00:01<00:10, 9454.55it/s]
# Extracting files (0/2:  12%|█▏        | 13460/116408 [00:01<00:10, 9518.56it/s]
# Extracting files (0/2:  12%|█▏        | 14421/116408 [00:02<00:10, 9470.13it/s]
# Extracting files (0/2:  13%|█▎        | 15394/116408 [00:02<00:10, 9544.89it/s]
# Extracting files (0/2:  14%|█▍        | 16353/116408 [00:02<00:10, 9546.42it/s]
# Extracting files (0/2:  15%|█▍        | 17320/116408 [00:02<00:10, 9581.64it/s]
# Extracting files (0/2:  16%|█▌        | 18281/116408 [00:02<00:10, 9424.34it/s]
# Extracting files (0/2:  17%|█▋        | 19226/116408 [00:02<00:10, 9428.49it/s]
# Extracting files (0/2:  17%|█▋        | 20186/116408 [00:02<00:10, 9478.71it/s]
# Extracting files (0/2:  18%|█▊        | 21157/116408 [00:02<00:09, 9545.10it/s]
# Extracting files (0/2:  19%|█▉        | 22113/116408 [00:02<00:09, 9499.59it/s]
# Extracting files (0/2:  74%|███████▍  | 86250/116408 [00:10<00:03, 8204.94it/s]
# Extracting files (0/2:  75%|███████▍  | 87120/116408 [00:10<00:05, 5731.08it/s]
# Extracting files (0/2:  76%|███████▌  | 88049/116408 [00:10<00:04, 6490.87it/s]
# Extracting files (0/2:  76%|███████▋  | 88982/116408 [00:10<00:03, 7153.15it/s]
# Extracting files (0/2:  77%|███████▋  | 89804/116408 [00:10<00:03, 7394.80it/s]
# Extracting files (0/2:  78%|███████▊  | 90743/116408 [00:11<00:03, 7917.05it/s]
# Extracting files (0/2:  79%|███████▉  | 91700/116408 [00:11<00:02, 8367.40it/s]
# Extracting files (0/2:  80%|███████▉  | 92654/116408 [00:11<00:02, 8694.63it/s]
# Extracting files (0/2:  80%|████████  | 93587/116408 [00:11<00:02, 8874.47it/s]
# Extracting files (0/2:  81%|████████  | 94519/116408 [00:11<00:02, 9001.78it/s]
# Extracting files (0/2:  82%|████████▏ | 95438/116408 [00:11<00:02, 8992.46it/s]
# Extracting files (0/2:  83%|████████▎ | 96365/116408 [00:11<00:02, 9071.67it/s]
# Extracting files (0/2:  84%|████████▎ | 97282/116408 [00:11<00:02, 8834.86it/s]

# %%
# 0: airplane
# 1: apple
# 2: bag
# 3: banana
# 4: baseball bat
# 5: baseball glove
# 6: bear
# 7: bed
# 8: bench
# 9: bicycle
# 10: bird
# 20: cat
# 27: dog
# 48: person

# %% [markdown]
# # 클래스별로 분리 하고 데이터 감축하기

# %%
# !mkdir /content/train/DistDataset
# !mkdir /content/train/DistDataset/first_class_labels

# %%
import os
import shutil

txt_folder = '/content/train/cocoDataset/cocolabels'
class_folder = '/content/train/DistDataset/first_class_labels/'

for class_id_to_copy in range(80):
    num_files = 0
    os.makedirs(os.path.join(class_folder, str(class_id_to_copy)), exist_ok=True)
    for filename in os.listdir(txt_folder):
        if filename.endswith('.txt'):
            with open(os.path.join(txt_folder, filename), 'r') as f:
                lines = f.readlines()
                if not lines:  # Skip the file if the file is empty
                    continue
                class_id = int(lines[0].split()[0])
                if class_id != class_id_to_copy:
                    continue
            print(f'Copying file {filename} to class {class_id_to_copy} folder...')
            shutil.copy(os.path.join(txt_folder, filename), os.path.join(class_folder, str(class_id_to_copy), filename))
            num_files += 1
    print(f'Total {num_files} files were copied to class {class_id_to_copy} folder.')
    print("--------------------------------------------------")

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/first_class_labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")

# %%
import shutil

# specify the source and destination paths
src_path = "/content/train/DistDataset/first_class_labels/48"
dst_path = "/content/train/DistDataset/48"

# copy the entire source folder to the destination path
shutil.copytree(src_path, dst_path)

# %% [markdown]
# ## 사람 데이터만 감축

# %%
folder_path = '/content/train/DistDataset/48'

num_files = 0
found_files = []
error_files = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        try:
            with open(os.path.join(folder_path, file_name), 'r') as f:
                lines = f.readlines()
                found_class_id = False
                for line in lines:
                    if len(line.split()) >= 1:
                        try:
                            class_id = int(line.split()[0])
                        except ValueError:
                            continue # skip to next line if the first word is not a valid integer
                        if class_id == 48 :
                            num_files += 1
                            found_class_id = True
                            break
                if found_class_id:
                    found_files.append(file_name)
        except:
            error_files.append(file_name)

print(f'Total number of files with <class-id>4</class-id>: {num_files}')
print(f'Files with <class-id>4</class-id>: {found_files}')
print(f'Number of error files: {len(error_files)}')
print(f'Error files: {error_files}')

# %%
import os

# number conversion function
def convert_class_id(class_id):
    if class_id == 48:
        return 4
    else:
        return 5


# Get all txt files in a specific folder
folder_path = '/content/train/DistDataset/48'
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Counter for files that caused errors
num_error_files = 0

# Counter for files that were successfully modified
num_success_files = 0

# Perform <class-id> conversion per file
for txt_file in txt_files:
    with open(os.path.join(folder_path, txt_file), 'r') as f:
        lines = f.readlines()
    new_lines = []
    try:
        for line in lines:
            class_id, x, y, width, height = map(float, line.strip().split(' '))
            new_class_id = convert_class_id(int(class_id))
            new_lines.append(f'{new_class_id} {x} {y} {width} {height}\n')
        with open(os.path.join(folder_path, txt_file), 'w') as f:
            f.writelines(new_lines)
            num_success_files += 1
    except ValueError:
        # Increment counter for files that caused errors
        num_error_files += 1
        continue

print(f'Total number of files that caused errors: {num_error_files}')
print(f'Total number of files successfully modified: {num_success_files}')

# %%
import os
import random

# specify the path to the folder
path = "/content/train/DistDataset/48"

# loop through all files in the folder
filenames = os.listdir(path)

# count the number of files
num_files = len(filenames)

# if the number of files exceeds 15000, delete random files
if num_files > 15000:
    excess_files = num_files - 15000
    random.shuffle(filenames)
    files_to_delete = filenames[:excess_files]
    for file_to_delete in files_to_delete:
        os.remove(os.path.join(path, file_to_delete))

# count the number of files after deletion
filenames = os.listdir(path)
num_files = len(filenames)
print(f'Number of files after deletion: {num_files}')

# %%
folder_path = '/content/train/DistDataset/48'

num_files = 0
found_files = []
error_files = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        try:
            with open(os.path.join(folder_path, file_name), 'r') as f:
                lines = f.readlines()
                found_class_id = False
                for line in lines:
                    if len(line.split()) >= 1:
                        try:
                            class_id = int(line.split()[0])
                        except ValueError:
                            continue # skip to next line if the first word is not a valid integer
                        if class_id == 4 :
                            num_files += 1
                            found_class_id = True
                            break
                if found_class_id:
                    found_files.append(file_name)
        except:
            error_files.append(file_name)

print(f'Total number of files with <class-id>4</class-id>: {num_files}')
print(f'Files with <class-id>4</class-id>: {found_files}')
print(f'Number of error files: {len(error_files)}')
print(f'Error files: {error_files}')

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/48"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")

# %% [markdown]
# ## 데이터 감축

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/first_class_labels"

# initialize a variable to keep track of the total number of files
total_files = 0

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # add the number of files to the total
    total_files += num_files

# print the total number of files
print(f"Total number of files: {total_files}")

# %%
import os
import random

# specify the path to the folder
path = "/content/train/DistDataset/first_class_labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # if the number of files exceeds 250, delete random files
    if num_files > 250:
        excess_files = num_files - 250
        random.shuffle(filenames)
        files_to_delete = filenames[:excess_files]
        for file_to_delete in files_to_delete:
            os.remove(os.path.join(foldername, file_to_delete))

# %%
shutil.rmtree('/content/train/DistDataset/first_class_labels/48')

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/first_class_labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")

# %%
# 폴더 파일들 한 폴더로 모으기
import os
import shutil

# !mkdir /content/train/DistDataset/merged_files

# specify the path to the source folder
src_path = "/content/train/DistDataset/first_class_labels"

# specify the path to the destination folder
dst_path = "/content/train/DistDataset/merged_files"

# create the destination folder if it doesn't already exist
if not os.path.exists(dst_path):
    os.makedirs(dst_path)

# loop through all folders and subfolders in the source path
for foldername, subfolders, filenames in os.walk(src_path):

    # loop through all files in the folder
    for filename in filenames:

        # get the full path of the file
        file_path = os.path.join(foldername, filename)

        # get the new destination path for the file
        new_file_path = os.path.join(dst_path, filename)

        # copy the file to the new destination
        shutil.copy(file_path, new_file_path)

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/merged_files"

# initialize a variable to keep track of the total number of files
total_files = 0

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # add the number of files to the total
    total_files += num_files

# print the total number of files
print(f"Total number of files: {total_files}")

# %% [markdown]
# ## coco 데이터셋 class id 값 수정하기
#
# 48: person
# 10: bird
# 20: cat
# 27: dog

# %% [markdown]
# # Class id에 할당된 값 (객체 명) 수정해주기

# %%
import os

# number conversion function
def convert_class_id(class_id):
    if class_id == 48:
        return 4
    else:
        return 5


# Get all txt files in a specific folder
folder_path = '/content/train/DistDataset/merged_files'
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Counter for files that caused errors
num_error_files = 0

# Counter for files that were successfully modified
num_success_files = 0

# Perform <class-id> conversion per file
for txt_file in txt_files:
    with open(os.path.join(folder_path, txt_file), 'r') as f:
        lines = f.readlines()
    new_lines = []
    try:
        for line in lines:
            class_id, x, y, width, height = map(float, line.strip().split(' '))
            new_class_id = convert_class_id(int(class_id))
            new_lines.append(f'{new_class_id} {x} {y} {width} {height}\n')
        with open(os.path.join(folder_path, txt_file), 'w') as f:
            f.writelines(new_lines)
            num_success_files += 1
    except ValueError:
        # Increment counter for files that caused errors
        num_error_files += 1
        continue

print(f'Total number of files that caused errors: {num_error_files}')
print(f'Total number of files successfully modified: {num_success_files}')

# %%
# 특정 클래스 id 를 가진 텍스트 파일 조회하기

folder_path = '/content/train/DistDataset/merged_files'

num_files = 0
found_files = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(os.path.join(folder_path, file_name), 'r') as f:
            lines = f.readlines()
            found_class_id = False
            for line in lines:
                if len(line.split()) >= 1:
                    try:
                        class_id = int(line.split()[0])
                    except ValueError:
                        continue # skip to next line if the first word is not a valid integer
                    if class_id == 5 :
                        num_files += 1
                        found_class_id = True
                        break
            if found_class_id:
                found_files.append(file_name)

print(f'Total number of files with <class-id>6</class-id>: {num_files}')
print(f'Files with <class-id>6</class-id>: {found_files}')

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/merged_files"

# initialize a variable to keep track of the total number of files
total_files = 0

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # add the number of files to the total
    total_files += num_files

# print the total number of files
print(f"Total number of files: {total_files}")

# %%
import os
import shutil

# specify the source and destination paths
src_path = "/content/train/DistDataset/48"
dst_path = "/content/train/DistDataset/merged_files"

# loop through all files in the source folder and copy them to the destination folder
for file_name in os.listdir(src_path):
    src_file_path = os.path.join(src_path, file_name)
    dst_file_path = os.path.join(dst_path, file_name)
    shutil.copy(src_file_path, dst_file_path)

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/merged_files"

# initialize a variable to keep track of the total number of files
total_files = 0

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # add the number of files to the total
    total_files += num_files

# print the total number of files
print(f"Total number of files: {total_files}")

# %%
# 특정 클래스 id 를 가진 텍스트 파일 조회하기

folder_path = '/content/train/DistDataset/merged_files'

num_files = 0
found_files = []

for file_name in os.listdir(folder_path):
    if file_name.endswith('.txt'):
        with open(os.path.join(folder_path, file_name), 'r') as f:
            lines = f.readlines()
            found_class_id = False
            for line in lines:
                if len(line.split()) >= 1:
                    try:
                        class_id = int(line.split()[0])
                    except ValueError:
                        continue # skip to next line if the first word is not a valid integer
                    if class_id == 5 :
                        num_files += 1
                        found_class_id = True
                        break
            if found_class_id:
                found_files.append(file_name)

print(f'Total number of files with <class-id>6</class-id>: {num_files}')
print(f'Files with <class-id>6</class-id>: {found_files}')

# %%
# coco데이터셋 파일들을 기존 데이터셋 폴더로 복사해주기

import shutil
import os

source_dir = "/content/train/cocoDataset/cocoimages"
target_dir = "/content/train/Dataset/images"

for filename in os.listdir(source_dir):
    # 이동할 파일 경로 지정
    file_path = os.path.join(source_dir, filename)
    # 파일이면 이동
    if os.path.isfile(file_path):
        shutil.copy(file_path, target_dir)

# %%
# 파일 개수 조회

import os

# Set folder path
source_folder = '/content/train/Dataset/images'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')

# %%
# coco데이터셋 파일들을 기존 데이터셋 폴더로 복사해주기

import shutil
import os

source_dir = "/content/train/DistDataset/merged_files"
target_dir = "/content/train/Dataset/labels"

for filename in os.listdir(source_dir):
    # 이동할 파일 경로 지정
    file_path = os.path.join(source_dir, filename)
    # 파일이면 이동
    if os.path.isfile(file_path):
        shutil.copy(file_path, target_dir)

# %%
# 파일 개수 조회

import os

# Set folder path
source_folder = '/content/train/Dataset/labels'

# Get list of files in folder
files = os.listdir(source_folder)

# Get number of files in folder
num_files = len(files)

print(f'The folder {source_folder} contains {num_files} files.')

# %% [markdown]
# # 학습, 검증, 테스트 파일 분리
#
# 1. class id 별로 폴더에 담기
# 2. train, val, test 데이터셋 생성하기
#
#   2-1. class id 별로 train, val, test 데이터 8:1:1 비율로 나누기
#
#   2-2. 나눠진 train, val, test 셋들 하나로 합치기
#
#   2-3. txt 파일 생성하기

# %% [markdown]
# ## 1. class id 별로 txt 파일을 새로운 폴더에 담기

# %%
import os
import shutil

# !mkdir /content/train/DistDataset/class_labels

txt_folder = '/content/train/Dataset/labels/'
class_folder = '/content/train/DistDataset/class_labels/'

for class_id_to_copy in range(7):
    num_files = 0
    os.makedirs(os.path.join(class_folder, str(class_id_to_copy)), exist_ok=True)
    for filename in os.listdir(txt_folder):
        if filename.endswith('.txt'):
            with open(os.path.join(txt_folder, filename), 'r') as f:
                lines = f.readlines()
                if not lines:  # Skip the file if the file is empty
                    continue
                class_id = int(lines[0].split()[0])
                if class_id != class_id_to_copy:
                    continue
            print(f'Copying file {filename} to class {class_id_to_copy} folder...')
            shutil.copy(os.path.join(txt_folder, filename), os.path.join(class_folder, str(class_id_to_copy), filename))
            num_files += 1
    print(f'Total {num_files} files were copied to class {class_id_to_copy} folder.')
    print("--------------------------------------------------")

# %%
import os

# specify the path to the folder
path = "/content/train/DistDataset/class_labels"

# loop through all folders and subfolders in the path
for foldername, subfolders, filenames in os.walk(path):

    # count the number of files in each folder
    num_files = len(filenames)

    # print the folder name and number of files
    print(f"{foldername}: {num_files}")

# %%
shutil.rmtree("/content/train/DistDataset/class_labels/6")

# %% [markdown]
# ## 2. class id 별로 train, val, test 데이터 8:1:1 비율로 나누고, txt 리스트 적힌 파일 생성하기

# %%
import os
import random

class_folder = '/content/train/DistDataset/class_labels/'
output_folder = '/content/train/DistDataset/'

train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

train_set = set()
val_set = set()
test_set = set()

# class_labels 폴더 내부의 모든 폴더들(0~87)에 대해서 실행
for class_id in range(5):
    class_dir = os.path.join(class_folder, str(class_id))
    file_list = os.listdir(class_dir)
    random.shuffle(file_list)

    num_files = len(file_list)

    train_files = file_list[:int(num_files*train_ratio)]
    val_files = file_list[int(num_files*train_ratio):int(num_files*(train_ratio+val_ratio))]
    test_files = file_list[int(num_files*(train_ratio+val_ratio)):]

    # 각각 분할된 파일들의 파일 이름을 set에 추가
    for filename in train_files:
        full_path = os.path.join(class_dir, filename)
        if full_path not in val_set and full_path not in test_set:
            train_set.add(full_path)
    for filename in val_files:
        full_path = os.path.join(class_dir, filename)
        if full_path not in train_set and full_path not in test_set:
            val_set.add(full_path)
    for filename in test_files:
        full_path = os.path.join(class_dir, filename)
        if full_path not in train_set and full_path not in val_set:
            test_set.add(full_path)

# train, val, test 각각에 대해 해당하는 파일 이름 리스트를 파일에 저장
with open(os.path.join(output_folder, 'train.txt'), 'w') as train_file:
    for item in train_set:
        train_file.write("%s\n" % item)
with open(os.path.join(output_folder, 'valid.txt'), 'w') as val_file:
    for item in val_set:
        val_file.write("%s\n" % item)
with open(os.path.join(output_folder, 'test.txt'), 'w') as test_file:
    for item in test_set:
        test_file.write("%s\n" % item)

# %% [markdown]
# ## .txt 파일 기준으로 작성된 데이터 세트들 jpg 형식으로 바꿔주기

# %%
# txt 파일 jpg 내용으로, 파일 경로 부분 수정

with open('/content/train/DistDataset/test.txt', 'r') as f:
    lines = f.readlines()

new_lines = []
for line in lines:
    new_line = "/content/train/Dataset/images/" + line.replace('.txt', '.jpg').split('/')[-1].strip()
    new_lines.append(new_line)

with open('/content/train/DistDataset/test.txt', 'w') as f:
    f.writelines('\n'.join(new_lines))

# train 파일 jpg 내용으로, 파일 경로 부분 수정

with open('/content/train/DistDataset/train.txt', 'r') as f:
    lines = f.readlines()

new_lines = []
for line in lines:
    new_line = "/content/train/Dataset/images/" + line.replace('.txt', '.jpg').split('/')[-1].strip()
    new_lines.append(new_line)

with open('/content/train/DistDataset/train.txt', 'w') as f:
    f.writelines('\n'.join(new_lines))

# valid 파일 jpg 내용으로, 파일 경로 부분 수정

with open('/content/train/DistDataset/valid.txt', 'r') as f:
    lines = f.readlines()

new_lines = []
for line in lines:
    new_line = "/content/train/Dataset/images/" + line.replace('.txt', '.jpg').split('/')[-1].strip()
    new_lines.append(new_line)

with open('/content/train/DistDataset/valid.txt', 'w') as f:
    f.writelines('\n'.join(new_lines))

# %%
# 파일 위치 옮기기
import shutil

src_file = "/content/train/DistDataset/test.txt"
dst_folder = "/content/train/Dataset"

shutil.copy(src_file, dst_folder)

src_file = "/content/train/DistDataset/train.txt"
dst_folder = "/content/train/Dataset"

shutil.copy(src_file, dst_folder)

src_file = "/content/train/DistDataset/valid.txt"
dst_folder = "/content/train/Dataset"

shutil.copy(src_file, dst_folder)

# %% [markdown]
# # yolov7 모듈 설치

# %%
# yolov7 clone 및 yolo 실행에 필요한 모듈 설치

main_path = main_path
os.chdir(main_path)

# !git clone https://github.com/WongKinYiu/yolov7.git
os.chdir(main_path + 'yolov7')
# !pip3 install -r requirements.txt

print('완료')

# %% [markdown]
# # yolov7 학습 실행

# %%
# yolo 학습 코드
import shutil

# tracking model 용 train
origin = google_drive_path + 'yolov7/train_copy.py'
copy = main_path + 'yolov7/train_copy.py'
shutil.copy(origin, copy)

os.chdir(main_path + 'yolov7')
# !sudo python3 train.py --img 416 --batch 64 --epochs 100 --data ../Dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt
# !sudo python train.py --workers 8 --device 0 --batch-size 64 --data ../Dataset/data.yaml --img 416 416 --cfg cfg/training/yolov7.yaml --weights yolov7.pt --name yolov7 --hyp data/hyp.scratch.p5.yaml
# 정상 train : !sudo python train.py --workers 8 --batch-size 32 --data ../Dataset/data.yaml --img 416 416 --cfg cfg/training/yolov7.yaml --weights '' --name yolov7 --hyp data/hyp.scratch.p5.yaml
# !sudo python train_copy.py --workers 8 --batch-size 32 --epochs 1 --data '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_data.yaml' --img 416 416 --cfg '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_cfg.yaml' --weights '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2wild4_day_30epoch_best.pt' --name yolov7xcustom1 --hyp data/hyp.scratch.p5.yaml

# !sudo python train.py --workers 8 --device 0 --batch-size 32 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7-custom.yaml --weights 'yolov7_training.pt' --name yolov7-custom --hyp data/hyp.scratch.custom.yaml
# !python train.py --workers 8 --device 0 --batch-size 16 --data data/custom_data.yaml --img 640 640 --cfg cfg/training/yolov7_custom_3.yaml --weights '' --name yolov7xcustom3 --hyp data/hyp.scratch.p5.yaml --epochs 200
# Out:
# 2023-04-05 01:23:23.753769: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-05 01:23:23.812064: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-05 01:23:24.721915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40513.5625MB)
#
# Namespace(weights='/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2wild4_day_30epoch_best.pt', cfg='/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_cfg.yaml', data='/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_data.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=1, batch_size=32, img_size=[416, 416], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7xcustom1', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7xcustom1', total_batch_size=32)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.0, paste_in=0.15, loss_ota=1
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     61126  models.yolo.IDetect                     [6, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 415 layers, 37223526 parameters, 37223526 gradients, 105.2 GFLOPS
#
# Transferred 564/566 items from /content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2wild4_day_30epoch_best.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# train: Scanning '../Dataset/train.cache' images and labels... 50596 found, 0 missing, 0 empty, 0 corrupted: 100% 50596/50596 [00:00<?, ?it/s]
# val: Scanning '../Dataset/valid.cache' images and labels... 6324 found, 0 missing, 0 empty, 1 corrupted: 100% 6324/6324 [00:00<?, ?it/s]
#
# autoanchor: Analyzing anchors... anchors/target = 4.69, Best Possible Recall (BPR) = 0.9704. Attempting to improve anchors, please wait...
# autoanchor: WARNING: Extremely small objects found. 3254 of 130369 labels are < 3 pixels in size.
# autoanchor: Running kmeans for 9 anchors on 128687 points...
# autoanchor: thr=0.25: 0.9590 best possible recall, 4.99 anchors past thr
# autoanchor: n=9, img_size=416, metric_all=0.323/0.675-mean/best, past_thr=0.482-mean: 14,20,  43,47,  48,110,  87,75,  136,104,  87,185,  211,148,  140,320,  330,314
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.7068: 100% 1000/1000 [00:08<00:00, 118.22it/s]
# autoanchor: thr=0.25: 0.9816 best possible recall, 4.94 anchors past thr
# autoanchor: n=9, img_size=416, metric_all=0.321/0.699-mean/best, past_thr=0.483-mean: 8,10,  15,28,  44,31,  37,75,  85,66,  75,114,  145,115,  92,221,  221,277
# autoanchor: New anchors saved to model. Update model *.yaml to use these anchors in the future.
#
# Image sizes 416 train, 416 test
# Using 8 dataloader workers
# Logging results to runs/train/yolov7xcustom1
# Starting training for 1 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#        0/0     1.01G   0.02911  0.006126  0.002281   0.03751        16       416: 100% 1582/1582 [10:04<00:00,  2.62it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 99/99 [00:40<00:00,  2.45it/s]
#                  all        6323       16508       0.857       0.799       0.814       0.706
#              raccoon        6323         881       0.999           1       0.996       0.943
#             wildBoar        6323        1672       0.944       0.994       0.994       0.925
#            waterDeer        6323        1830        0.98       0.996       0.996       0.936
#       asianBlackBear        6323        1669       0.896       0.968       0.976        0.93
#               person        6323        5086       0.751       0.602       0.654       0.384
#               others        6323        5370       0.569       0.235       0.268       0.116
# 1 epochs completed in 0.181 hours.
#
# Optimizer stripped from runs/train/yolov7xcustom1/weights/last.pt, 74.8MB
# Optimizer stripped from runs/train/yolov7xcustom1/weights/best.pt, 74.8MB

# %%
# weight 파일 구글드라이브로 옮기기

import shutil

i = len(os.listdir(google_drive_path + 'yolov7/runs/train/'))
folder_name = google_drive_path + 'yolov7/runs/train/exp' + str(i + 2)
os.mkdir(folder_name)

origin = main_path + '/yolov7/runs/train/yolov7xcustom1/weights/best.pt'
copy = folder_name + '/best.pt'
shutil.copy(origin, copy)
# Out:
# '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/코드/03. yolov7_train/yolov7/runs/train/exp28/best.pt'

# %%
# yolo 테스트 코드
# 본 코드 오류시, 아래 셀의 설명을 읽어주세요.

os.chdir(main_path + 'yolov7')

# !sudo python3 test.py --data '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_data.yaml' --batch 128 --weights '/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/코드/03. yolov7_train/yolov7/runs/train/exp21/coco2wild4_day_30epoch_best.pt' --task test --img 416 --save-txt --save-conf
# Out:
# Namespace(weights=['/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/코드/03. yolov7_train/yolov7/runs/train/exp21/coco2wild4_day_30epoch_best.pt'], data='/content/drive/MyDrive/[SeSAC] Final_PJT 공유폴더/03. 파이널_야생동물 객체 탐지, 추적 모델/데이터셋/야생5종+coco세팅파일/coco2Wild4_day_data.yaml', batch_size=128, img_size=416, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=True, save_json=False, project='runs/test', name='exp', exist_ok=False, no_trace=False, v5_metric=False)
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40513.5625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36508742 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# test: Scanning '../Dataset/test.cache' images and labels... 6326 found, 0 missing, 0 empty, 0 corrupted: 100% 6326/6326 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100% 50/50 [01:46<00:00,  2.12s/it]
#                  all        6326       16360       0.855        0.81       0.824       0.721
#              raccoon        6326         882       0.999           1       0.998        0.95
#            waterDeer        6326        1706       0.935       0.999       0.994       0.938
#             wildBoar        6326        1809       0.963       0.996       0.996       0.943
#       asianBlackBear        6326        1678        0.89       0.976       0.978       0.941
#               person        6326        5125       0.757       0.623       0.669       0.412
#               others        6326        5160       0.586       0.263       0.308       0.143
# Speed: 1.1/0.9/2.1 ms inference/NMS/total per 416x416 image at batch-size 128
# Results saved to runs/test/exp2
# 6326 labels saved to runs/test/exp2/labels

# %%
shutil.rmtree('/content/train/yolov7/runs/train')
