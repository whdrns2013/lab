# %%
import torch

# %%
# coco 데이터셋 보기

ckpt = torch.load('C:/Users/user/Desktop/yolov7/easy-yolov7-main/coco.weights', map_location=torch.device('cpu'))
# model_state_dict = ckpt['state_dict']

if 'tensor' in ckpt:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
print(ckpt.keys())
print(ckpt)

# %%
# 욜로7 직접 훈련시킨 파일 보기

ckpt = torch.load('C:/Users/user/Desktop/yolov7/easy-yolov7-main/best.weights')
# model_state_dict = ckpt['state_dict']

if 'tensor' in ckpt:
    print("yes")
else:
    print("no")

# %%
print(ckpt.keys())
print(ckpt)
# Out:
# dict_keys(['model', 'optimizer', 'training_results', 'epoch'])
# {'model': Model(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (2): Conv(
#       (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): LeakyReLU(negative_slope=0.1, inplace=True)
#     )
#     (3): Conv(
# ...
